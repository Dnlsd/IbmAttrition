# %% [markdown]
# ## O dataset
#
# O dataset a ser utilizado é o *IBM HR Analytics Employee Attrition & Performance*, disponível no Kaggle. O dataset contém informações sobre funcionários de uma empresa fictícia, como idade, gênero, estado civil, nível de satisfação, entre outros. O objetivo é prever a probabilidade de um funcionário sair da empresa.
#
# [Link do Kaggle](https://www.kaggle.com/datasets/pavansubhasht/ibm-hr-analytics-attrition-dataset/data)
#
# Os termos *attrition* ("atrito") e *turnover* ("rotatividade") são frequentemente usados de forma intercambiável no contexto de recursos humanos e gestão de força de trabalho, mas eles se referem a conceitos ligeiramente diferentes em relação às mudanças no número e na composição dos empregados dentro de uma organização. Compreender a distinção entre esses dois é importante para analisar e relatar com precisão a dinâmica da força de trabalho.
#
# ### Atrito
#
# Atrito refere-se à redução gradual de empregados por meio de circunstâncias naturais, como aposentadoria, demissão voluntária por motivos pessoais, ou a decisão de não substituir empregados que estão de saída. Atrito pode levar a uma diminuição no tamanho da força de trabalho, mas é caracterizado por sua natureza voluntária e muitas vezes incontrolável. Organizações podem permitir o atrito para reduzir o tamanho de sua força de trabalho sem recorrer a demissões, vendo isso como uma forma menos disruptiva de ajustar seus níveis de pessoal.
#
# Em análises, quando você está analisando um conjunto de dados para atrito, você frequentemente olha para as razões por trás das saídas voluntárias e a taxa na qual estas ocorrem naturalmente ao longo do tempo. Taxas de atrito podem fornecer insights sobre a satisfação dos empregados e tendências de longo prazo da força de trabalho.
#
# ### Rotatividade
#
# Rotatividade, por outro lado, engloba um escopo mais amplo de partidas de empregados, incluindo tanto renúncias voluntárias quanto demissões involuntárias (como demissões ou términos por justa causa). Porém, ocorre a substituição da força de trabalho. Rotatividade é uma medida de quantos empregados estão deixando a companhia por qualquer motivo. Uma alta taxa de rotatividade pode indicar problemas com satisfação no trabalho, cultura do local de trabalho, ou estabilidade organizacional, e frequentemente requer ação da gestão para endereçar as causas subjacentes.
#
# Rotatividade é calculada dividindo o número de empregados que saem pelo número médio de empregados, geralmente em uma base anual, e expressando isso como uma porcentagem. Esta métrica é crucial para entender como as saídas de empregados, tanto voluntárias quanto involuntárias, afetam a capacidade da organização de manter uma força de trabalho estável e eficaz.
#
# ### Diferenças Chave
#
# - **Natureza**: Atrito geralmente é voluntário e pode ser devido a fatores naturais ou incontroláveis, enquanto rotatividade inclui tanto saídas voluntárias quanto demissões involuntárias.
# - **Implicações para Gestão**: Atrito pode ser parte de uma estratégia de ajuste natural da força de trabalho e nem sempre é negativo, enquanto alta rotatividade é frequentemente um sinal de problemas dentro da organização que precisam ser abordados.
# - **Foco Estratégico**: Análise de atrito pode focar em entender tendências de longo prazo da força de trabalho e planejamento de aposentadoria, enquanto análise de rotatividade é frequentemente usada para identificar questões imediatas com satisfação de empregados, engajamento, ou práticas de gestão que podem estar impactando a retenção de staff.
#
# Enquanto ambos atrito e rotatividade lidam com empregados deixando a organização, eles diferem em seu escopo e as implicações estratégicas para gerenciar e entender a dinâmica da força de trabalho. No seu conjunto de dados de empregados, distinguir entre atrito e rotatividade pode ajudar na customização de estratégias para planejamento da força de trabalho, retenção e desenvolvimento organizacional.

# %% [markdown]
# |    | Name                       | Description                                                                                                                                                    |
# |---:|:---------------------------|:---------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |  0 | Age                        | Numerical Value                                                                                                                                                |
# |  1 | Attrition                  | Employee leaving the company - Text - No, Yes                                                                                                                     |
# |  2 | BusinessTravel            | Text - Non-Travel, Travel_Frequently, Travel_Rarely                                                                                                             |
# |  3 | DailyRate                 | Numerical Value - Salary Level                                                                                                                                 |
# |  4 | Department                 | Text - Sales, Research & Development, Human Resources                                                                                                         |
# |  5 | DistanceFromHome         | Numerical Value - the distance from work to home in miles
# |  6 | Education                  | Numerical Value - 1=Below college, 2=College, 3=Bachelor, 4=Master, 5=PhD   |
# |  7 | EducationField            | Text - Life Sciences, Medical, Marketing, Techincal Degree, Human Resources, Other                                                                                   |
# |  8 | EmployeeCount             | Numerical Value - 1                                                                                                                                               |
# |  9 | EmployeeNumber            | Numerical Value - Employee ID                                                                                                                                  |
# | 10 | EnvironmentSatisfaction    | Numerical Value - 1=Low, 2=Medium, 3=High, 4=Very High |
# | 11 | Gender                     | Text - Female, Male                                                                                                                                             |
# | 12 | HourlyRate                | Numerical Value - Hourly Salary                                                                                                                                |
# | 13 | JobInvolvement            | Numerical Value - 1=Low, 2=Medium, 3=High, 4=Very High                                                                                                         |
# | 14 | JobLevel                  | Numerical Value - 1, 2, 3, 4, 5. Means different job levels                                                                                                     |
# | 15 | JobRole                   | Text - Sales Executive, Research Scientist, Laboratory Technician, Manufacturing Director, Healthcare Representative, Manager, Sales Representative, Research Director, Human Resources |
# | 16 | JobSatisfaction           | Numerical Value - 1=Low, 2=Medium, 3=High, 4=Very High                                                                                                         |
# | 17 | MaritalStatus             | Text - Single, Married, Divorced                                                                                                                                      |
# | 18 | MonthlyIncome             | Numerical Value - Monthly Salary                                                                                                                               |
# | 19 | MonthlyRate                | Numerical Value - Monthly Rate                                                                                                                                  |
# | 20 | NumCompaniesWorked        | Numerical Value - Number of companies worked at                                                                                                                |
# | 21 | Over18                    | Text - Y                                                                                                                                                    |
# | 22 | Overtime                   | Text - No, Yes                                                                                                                                                    |
# | 23 | PercentSalaryHike        | Numerical Value - Percentage increase in salary                                                                                                                |
# | 24 | PerformanceRating         | Numerical Value - 1=Low, 2=Good, 3=Excellent, 4=Outstanding                                                                                                    |
# | 25 | RelationshipSatisfaction  | Numerical Value - 1=Low, 2=Medium, 3=High, 4=Very High                                                                                                         |
# | 26 | StandardHours             | Numerical Value - 80                                                                                                                                            |
# | 27 | StockOptionsLevel        | Numerical Value - 0, 1, 2, 3                                                                                                                                    |
# | 28 | TotalWorkingYears        | Numerical Value - Total years worked                                                                                                                            |
# | 29 | TrainingTimesLastYear   | Numerical Value - How many times the employee has been trained last year                                                                                       |
# | 30 | WorkLifeBalance          | Numerical Value - 1=Bad, 2=Good, 3=Better, 4=Best                                                                                                              |
# | 31 | YearsAtCompany           | Numerical Value - Number of years at the company                                                                                                                |
# | 32 | YearsInCurrentRole      | Numerical Value -Number of years in current role                                                                                                                |
# | 33 | YearsSinceLastPromotion | Numerical Value - Years since last promotion                                                                                                                    |
# | 34 | YearsWithCurrManager | Numerical Value - Years with current manager                                                                                                                    |

# %% [markdown]
# Esclarecimento sobre níveis educacionais (college vs bachelor):
#
# - https://educacao.uol.com.br/noticias/2013/02/27/entenda-as-diferencas-entre-os-cursos-universitarios-nos-eua.htm
# - https://www.forbes.com/advisor/education/student-resources/differences-between-college-and-university/

# %% [markdown]
# ## Checagens básicas

# %% [markdown]
# - shape
# - colunas
# - tipos
# - valores nulos
# - valores "estranhos"
# - valores únicos
# - valores duplicados
# - contagem de valores relevantes

# %%
import pandas as pd

DADOS = "dados/employee_attrition.csv"

df = pd.read_csv(DADOS)

df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
# 3  ...                         3            80                 0
# 4  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
# 2                  7                      3               3               0
# 3                  8                      3               3               8
# 4                  6                      3               3               2
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
# 1                  7                        1                     7
# 2                  0                        0                     0
# 3                  7                        3                     0
# 4                  2                        2                     2
#
# [5 rows x 35 columns]

# %%
with pd.option_context("display.max_columns", 35):
    display(df.head())
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2  Female          94               3         2
# 1                        3    Male          61               2         2
# 2                        4    Male          92               2         1
# 3                        4  Female          56               3         1
# 4                        1    Male          40               3         1
#
#                  JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0        Sales Executive                4        Single           5993
# 1     Research Scientist                2       Married           5130
# 2  Laboratory Technician                3        Single           2090
# 3     Research Scientist                3       Married           2909
# 4  Laboratory Technician                2       Married           3468
#
#    MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0        19479                   8      Y      Yes                 11
# 1        24907                   1      Y       No                 23
# 2         2396                   6      Y      Yes                 15
# 3        23159                   1      Y      Yes                 11
# 4        16632                   9      Y       No                 12
#
#    PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                  3                         1             80
# 1                  4                         4             80
# 2                  3                         2             80
# 3                  3                         3             80
# 4                  3                         4             80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 0                  8                      0
# 1                 1                 10                      3
# 2                 0                  7                      3
# 3                 0                  8                      3
# 4                 1                  6                      3
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                1               6                   4
# 1                3              10                   7
# 2                3               0                   0
# 3                3               8                   7
# 4                3               2                   2
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     5
# 1                        1                     7
# 2                        0                     0
# 3                        3                     0
# 4                        2                     2

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
#  14  JobLevel                  1470 non-null   int64
#  15  JobRole                   1470 non-null   object
#  16  JobSatisfaction           1470 non-null   int64
#  17  MaritalStatus             1470 non-null   object
#  18  MonthlyIncome             1470 non-null   int64
#  19  MonthlyRate               1470 non-null   int64
#  20  NumCompaniesWorked        1470 non-null   int64
#  21  Over18                    1470 non-null   object
#  22  OverTime                  1470 non-null   object
#  23  PercentSalaryHike         1470 non-null   int64
#  24  PerformanceRating         1470 non-null   int64
#  25  RelationshipSatisfaction  1470 non-null   int64
#  26  StandardHours             1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  TotalWorkingYears         1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsAtCompany            1470 non-null   int64
#  32  YearsInCurrentRole        1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
# dtypes: int64(26), object(9)
# memory usage: 402.1+ KB

# %%
with pd.option_context("float_format", "{:.2f}".format, "display.max_columns", 35):
    display(df.describe())
# Out:
#           Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# count 1470.00    1470.00           1470.00    1470.00        1470.00
# mean    36.92     802.49              9.19       2.91           1.00
# std      9.14     403.51              8.11       1.02           0.00
# min     18.00     102.00              1.00       1.00           1.00
# 25%     30.00     465.00              2.00       2.00           1.00
# 50%     36.00     802.00              7.00       3.00           1.00
# 75%     43.00    1157.00             14.00       4.00           1.00
# max     60.00    1499.00             29.00       5.00           1.00
#
#        EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# count         1470.00                  1470.00     1470.00         1470.00
# mean          1024.87                     2.72       65.89            2.73
# std            602.02                     1.09       20.33            0.71
# min              1.00                     1.00       30.00            1.00
# 25%            491.25                     2.00       48.00            2.00
# 50%           1020.50                     3.00       66.00            3.00
# 75%           1555.75                     4.00       83.75            3.00
# max           2068.00                     4.00      100.00            4.00
#
#        JobLevel  JobSatisfaction  MonthlyIncome  MonthlyRate  \
# count   1470.00          1470.00        1470.00      1470.00
# mean       2.06             2.73        6502.93     14313.10
# std        1.11             1.10        4707.96      7117.79
# min        1.00             1.00        1009.00      2094.00
# 25%        1.00             2.00        2911.00      8047.00
# 50%        2.00             3.00        4919.00     14235.50
# 75%        3.00             4.00        8379.00     20461.50
# max        5.00             4.00       19999.00     26999.00
#
#        NumCompaniesWorked  PercentSalaryHike  PerformanceRating  \
# count             1470.00            1470.00            1470.00
# mean                 2.69              15.21               3.15
# std                  2.50               3.66               0.36
# min                  0.00              11.00               3.00
# 25%                  1.00              12.00               3.00
# 50%                  2.00              14.00               3.00
# 75%                  4.00              18.00               3.00
# max                  9.00              25.00               4.00
#
#        RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# count                   1470.00        1470.00           1470.00
# mean                       2.71          80.00              0.79
# std                        1.08           0.00              0.85
# min                        1.00          80.00              0.00
# 25%                        2.00          80.00              0.00
# 50%                        3.00          80.00              1.00
# 75%                        4.00          80.00              1.00
# max                        4.00          80.00              3.00
#
#        TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# count            1470.00                1470.00          1470.00
# mean               11.28                   2.80             2.76
# std                 7.78                   1.29             0.71
# min                 0.00                   0.00             1.00
# 25%                 6.00                   2.00             2.00
# 50%                10.00                   3.00             3.00
# 75%                15.00                   3.00             3.00
# max                40.00                   6.00             4.00
#
#        YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# count         1470.00             1470.00                  1470.00
# mean             7.01                4.23                     2.19
# std              6.13                3.62                     3.22
# min              0.00                0.00                     0.00
# 25%              3.00                2.00                     0.00
# 50%              5.00                3.00                     1.00
# 75%              9.00                7.00                     3.00
# max             40.00               18.00                    15.00
#
#        YearsWithCurrManager
# count               1470.00
# mean                   4.12
# std                    3.57
# min                    0.00
# 25%                    2.00
# 50%                    3.00
# 75%                    7.00
# max                   17.00

# %% [markdown]
# **Explicando quartis e outliers**
#
# Quartis são valores que dividem um conjunto de dados em quatro partes iguais. O primeiro quartil (Q1) é o valor que deixa 25% dos dados abaixo e 75% acima. O segundo quartil (Q2) é a mediana, que deixa 50% dos dados abaixo e 50% acima. O terceiro quartil (Q3) deixa 75% dos dados abaixo e 25% acima.
#
# Por exemplo, se temos um conjunto de dados com 100 valores, o primeiro quartil (Q1) será o valor que deixa 25 valores abaixo e 75 acima. O segundo quartil (Q2) será o valor que deixa 50 valores abaixo e 50 acima. O terceiro quartil (Q3) será o valor que deixa 75 valores abaixo e 25 acima.
#
# Outliers são valores que fogem do padrão do conjunto de dados. São valores muito altos ou muito baixos que podem influenciar negativamente na análise dos dados. Por exemplo, se temos um conjunto de dados com salários de funcionários de uma empresa, e um dos salários é muito maior que os outros, esse salário pode ser considerado um outlier.
#
# Estatisticamente, um outlier é um valor que está a mais de 1,5 vezes o intervalo interquartil acima do terceiro quartil (Q3) ou a mais de 1,5 vezes o intervalo interquartil abaixo do primeiro quartil (Q1). O intervalo interquartil é a diferença entre o terceiro quartil (Q3) e o primeiro quartil (Q1).

# %%
df.describe(exclude="number")
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       1470           1470                    1470           1470   1470
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        1233           1043                     961            606    882
#
#                 JobRole MaritalStatus Over18 OverTime
# count              1470          1470   1470     1470
# unique                9             3      1        2
# top     Sales Executive       Married      Y       No
# freq                326           673   1470     1054

# %% [markdown]
# OBS.: *O dataset é desbalanceado, ou seja, a quantidade de funcionários que saíram da empresa é muito menor que a quantidade de funcionários que permaneceram na empresa. Isso pode influenciar na análise dos dados.*
#
# A coluna "Attrition" é a coluna que indica se o funcionário saiu da empresa ou não. Ela é a chama coluna alvo, ou target. Esse nome é dado pois é a coluna que queremos avaliar e prever.

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Exercícios
#
# - remover colunas com valores únicos
# - encontrar os registros dos 10 funcionários mais velhos e dos 10 mais novos
# - encontrar os registros dos 10 funcionários com mais tempo de empresa e dos 10 com menos tempo
# - encontrar os registros dos 10 funcionários com mais tempo no cargo (sem promoção) e dos 10 com menos tempo
# - agrupamentos (em cada caso, mostrar também o agrupamento por saída ou não do funcionário)
#   - contagem de funcionários por departamento
#   - média de salário por departamento
#   - contagem de gênero por departamento
#   - contagem de gênero por cargo
#   - média de salário por cargo
#   - média de salário por cargo e nível
#   - média de salário por nível educacional

# %%
df["EmployeeNumber"].nunique()
# Out:
# 1470

# %%
df = df.drop(["EmployeeCount", "Over18", "StandardHours", "EmployeeNumber"], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   object
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
#  13  JobRole                   1470 non-null   object
#  14  JobSatisfaction           1470 non-null   int64
#  15  MaritalStatus             1470 non-null   object
#  16  MonthlyIncome             1470 non-null   int64
#  17  MonthlyRate               1470 non-null   int64
#  18  NumCompaniesWorked        1470 non-null   int64
#  19  OverTime                  1470 non-null   object
#  20  PercentSalaryHike         1470 non-null   int64
#  21  PerformanceRating         1470 non-null   int64
#  22  RelationshipSatisfaction  1470 non-null   int64
#  23  StockOptionLevel          1470 non-null   int64
#  24  TotalWorkingYears         1470 non-null   int64
#  25  TrainingTimesLastYear     1470 non-null   int64
#  26  WorkLifeBalance           1470 non-null   int64
#  27  YearsAtCompany            1470 non-null   int64
#  28  YearsInCurrentRole        1470 non-null   int64
#  29  YearsSinceLastPromotion   1470 non-null   int64
#  30  YearsWithCurrManager      1470 non-null   int64
# dtypes: int64(23), object(8)
# memory usage: 356.1+ KB

# %%
df[df["Age"] == df["Age"].max()]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 411    60        No      Travel_Rarely        422  Research & Development
# 427    60        No  Travel_Frequently       1499                   Sales
# 536    60        No      Travel_Rarely       1179                   Sales
# 879    60        No      Travel_Rarely        696                   Sales
# 1209   60        No      Travel_Rarely        370  Research & Development
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 411                  7          3  Life Sciences                        1
# 427                 28          3      Marketing                        3
# 536                 16          4      Marketing                        1
# 879                  7          4      Marketing                        2
# 1209                 1          4        Medical                        3
#
#       Gender  ...  PerformanceRating  RelationshipSatisfaction  \
# 411   Female  ...                  3                         4
# 427   Female  ...                  3                         4
# 536     Male  ...                  3                         4
# 879     Male  ...                  3                         2
# 1209    Male  ...                  4                         3
#
#       StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  \
# 411                  0                33                      5
# 427                  0                22                      5
# 536                  0                10                      1
# 879                  1                12                      3
# 1209                 1                19                      2
#
#      WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 411                1              29                   8
# 427                4              18                  13
# 536                3               2                   2
# 879                3              11                   7
# 1209               4               1                   0
#
#       YearsSinceLastPromotion YearsWithCurrManager
# 411                        11                   10
# 427                        13                   11
# 536                         2                    2
# 879                         1                    9
# 1209                        0                    0
#
# [5 rows x 31 columns]

# %%
df[df["Age"] == df["Age"].min()]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 296    18       Yes      Travel_Rarely        230  Research & Development
# 301    18        No      Travel_Rarely        812                   Sales
# 457    18       Yes  Travel_Frequently       1306                   Sales
# 727    18        No         Non-Travel        287  Research & Development
# 828    18       Yes         Non-Travel        247  Research & Development
# 972    18        No         Non-Travel       1124  Research & Development
# 1153   18       Yes  Travel_Frequently        544                   Sales
# 1311   18        No         Non-Travel       1431  Research & Development
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 296                  3          3  Life Sciences                        3
# 301                 10          3        Medical                        4
# 457                  5          3      Marketing                        2
# 727                  5          2  Life Sciences                        2
# 828                  8          1        Medical                        3
# 972                  1          3  Life Sciences                        4
# 1153                 3          2        Medical                        2
# 1311                14          3        Medical                        2
#
#       Gender  ...  PerformanceRating  RelationshipSatisfaction  \
# 296     Male  ...                  3                         3
# 301   Female  ...                  3                         1
# 457     Male  ...                  3                         4
# 727     Male  ...                  3                         4
# 828     Male  ...                  3                         4
# 972   Female  ...                  3                         3
# 1153  Female  ...                  3                         3
# 1311  Female  ...                  3                         3
#
#       StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  \
# 296                  0                 0                      2
# 301                  0                 0                      2
# 457                  0                 0                      3
# 727                  0                 0                      2
# 828                  0                 0                      0
# 972                  0                 0                      5
# 1153                 0                 0                      2
# 1311                 0                 0                      4
#
#      WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 296                3               0                   0
# 301                3               0                   0
# 457                3               0                   0
# 727                3               0                   0
# 828                3               0                   0
# 972                4               0                   0
# 1153               4               0                   0
# 1311               1               0                   0
#
#       YearsSinceLastPromotion YearsWithCurrManager
# 296                         0                    0
# 301                         0                    0
# 457                         0                    0
# 727                         0                    0
# 828                         0                    0
# 972                         0                    0
# 1153                        0                    0
# 1311                        0                    0
#
# [8 rows x 31 columns]

# %%
df.nlargest(10, "Age")
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 411    60        No      Travel_Rarely        422  Research & Development
# 427    60        No  Travel_Frequently       1499                   Sales
# 536    60        No      Travel_Rarely       1179                   Sales
# 879    60        No      Travel_Rarely        696                   Sales
# 1209   60        No      Travel_Rarely        370  Research & Development
# 6      59        No      Travel_Rarely       1324  Research & Development
# 63     59        No      Travel_Rarely       1435                   Sales
# 70     59        No  Travel_Frequently       1225                   Sales
# 105    59        No         Non-Travel       1420         Human Resources
# 225    59        No      Travel_Rarely        142  Research & Development
#
#       DistanceFromHome  Education   EducationField  EnvironmentSatisfaction  \
# 411                  7          3    Life Sciences                        1
# 427                 28          3        Marketing                        3
# 536                 16          4        Marketing                        1
# 879                  7          4        Marketing                        2
# 1209                 1          4          Medical                        3
# 6                    3          3          Medical                        3
# 63                  25          3    Life Sciences                        1
# 70                   1          1    Life Sciences                        1
# 105                  2          4  Human Resources                        3
# 225                  3          3    Life Sciences                        3
#
#       Gender  ...  PerformanceRating  RelationshipSatisfaction  \
# 411   Female  ...                  3                         4
# 427   Female  ...                  3                         4
# 536     Male  ...                  3                         4
# 879     Male  ...                  3                         2
# 1209    Male  ...                  4                         3
# 6     Female  ...                  4                         1
# 63    Female  ...                  3                         4
# 70    Female  ...                  3                         4
# 105   Female  ...                  4                         4
# 225     Male  ...                  3                         1
#
#       StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  \
# 411                  0                33                      5
# 427                  0                22                      5
# 536                  0                10                      1
# 879                  1                12                      3
# 1209                 1                19                      2
# 6                    3                12                      3
# 63                   0                28                      3
# 70                   0                20                      2
# 105                  1                30                      3
# 225                  1                 7                      6
#
#      WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 411                1              29                   8
# 427                4              18                  13
# 536                3               2                   2
# 879                3              11                   7
# 1209               4               1                   0
# 6                  2               1                   0
# 63                 2              21                  16
# 70                 2               4                   3
# 105                3               3                   2
# 225                3               1                   0
#
#       YearsSinceLastPromotion YearsWithCurrManager
# 411                        11                   10
# 427                        13                   11
# 536                         2                    2
# 879                         1                    9
# 1209                        0                    0
# 6                           0                    0
# 63                          7                    9
# 70                          1                    3
# 105                         2                    2
# 225                         0                    0
#
# [10 rows x 31 columns]

# %%
df.nsmallest(10, "Age")
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 296    18       Yes      Travel_Rarely        230  Research & Development
# 301    18        No      Travel_Rarely        812                   Sales
# 457    18       Yes  Travel_Frequently       1306                   Sales
# 727    18        No         Non-Travel        287  Research & Development
# 828    18       Yes         Non-Travel        247  Research & Development
# 972    18        No         Non-Travel       1124  Research & Development
# 1153   18       Yes  Travel_Frequently        544                   Sales
# 1311   18        No         Non-Travel       1431  Research & Development
# 127    19       Yes      Travel_Rarely        528                   Sales
# 149    19        No      Travel_Rarely       1181  Research & Development
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 296                  3          3  Life Sciences                        3
# 301                 10          3        Medical                        4
# 457                  5          3      Marketing                        2
# 727                  5          2  Life Sciences                        2
# 828                  8          1        Medical                        3
# 972                  1          3  Life Sciences                        4
# 1153                 3          2        Medical                        2
# 1311                14          3        Medical                        2
# 127                 22          1      Marketing                        4
# 149                  3          1        Medical                        2
#
#       Gender  ...  PerformanceRating  RelationshipSatisfaction  \
# 296     Male  ...                  3                         3
# 301   Female  ...                  3                         1
# 457     Male  ...                  3                         4
# 727     Male  ...                  3                         4
# 828     Male  ...                  3                         4
# 972   Female  ...                  3                         3
# 1153  Female  ...                  3                         3
# 1311  Female  ...                  3                         3
# 127     Male  ...                  3                         4
# 149   Female  ...                  3                         4
#
#       StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  \
# 296                  0                 0                      2
# 301                  0                 0                      2
# 457                  0                 0                      3
# 727                  0                 0                      2
# 828                  0                 0                      0
# 972                  0                 0                      5
# 1153                 0                 0                      2
# 1311                 0                 0                      4
# 127                  0                 0                      2
# 149                  0                 1                      3
#
#      WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 296                3               0                   0
# 301                3               0                   0
# 457                3               0                   0
# 727                3               0                   0
# 828                3               0                   0
# 972                4               0                   0
# 1153               4               0                   0
# 1311               1               0                   0
# 127                2               0                   0
# 149                3               1                   0
#
#       YearsSinceLastPromotion YearsWithCurrManager
# 296                         0                    0
# 301                         0                    0
# 457                         0                    0
# 727                         0                    0
# 828                         0                    0
# 972                         0                    0
# 1153                        0                    0
# 1311                        0                    0
# 127                         0                    0
# 149                         0                    0
#
# [10 rows x 31 columns]

# %%
df.nlargest(10, "YearsAtCompany")
# Out:
#       Age Attrition BusinessTravel  DailyRate              Department  \
# 126    58       Yes  Travel_Rarely        147  Research & Development
# 98     58        No  Travel_Rarely        682                   Sales
# 270    55        No  Travel_Rarely        452  Research & Development
# 1116   55        No  Travel_Rarely        685                   Sales
# 561    52        No  Travel_Rarely        621                   Sales
# 190    52        No  Travel_Rarely        699  Research & Development
# 237    52        No     Non-Travel        771                   Sales
# 914    55        No     Non-Travel        177  Research & Development
# 962    51        No  Travel_Rarely        770         Human Resources
# 1111   53       Yes  Travel_Rarely        607  Research & Development
#
#       DistanceFromHome  Education    EducationField  EnvironmentSatisfaction  \
# 126                 23          4           Medical                        4
# 98                  10          4           Medical                        4
# 270                  1          3           Medical                        4
# 1116                26          5         Marketing                        3
# 561                  3          4         Marketing                        3
# 190                  1          4     Life Sciences                        3
# 237                  2          4     Life Sciences                        1
# 914                  8          1           Medical                        4
# 962                  5          3     Life Sciences                        3
# 1111                 2          5  Technical Degree                        3
#
#       Gender  ...  PerformanceRating  RelationshipSatisfaction  \
# 126   Female  ...                  3                         4
# 98      Male  ...                  3                         3
# 270     Male  ...                  3                         3
# 1116    Male  ...                  4                         3
# 561     Male  ...                  3                         1
# 190     Male  ...                  3                         1
# 237     Male  ...                  3                         4
# 914     Male  ...                  3                         4
# 962     Male  ...                  3                         2
# 1111  Female  ...                  3                         2
#
#       StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  \
# 126                  1                40                      3
# 98                   0                38                      1
# 270                  0                37                      2
# 1116                 1                36                      3
# 561                  0                34                      3
# 190                  1                34                      5
# 237                  0                33                      2
# 914                  1                34                      3
# 962                  1                33                      2
# 1111                 1                34                      4
#
#      WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 126                2              40                  10
# 98                 2              37                  10
# 270                3              36                  10
# 1116               3              36                   6
# 561                4              34                   6
# 190                3              33                  18
# 237                4              33                   7
# 914                3              33                   9
# 962                3              33                   9
# 1111               3              33                   7
#
#       YearsSinceLastPromotion YearsWithCurrManager
# 126                        15                    6
# 98                          1                    8
# 270                         4                   13
# 1116                        2                   13
# 561                         1                   16
# 190                        11                    9
# 237                        15                   12
# 914                        15                    0
# 962                         0                   10
# 1111                        1                    9
#
# [10 rows x 31 columns]

# %%
df.nsmallest(10, "YearsAtCompany")
# Out:
#      Age Attrition     BusinessTravel  DailyRate              Department  \
# 2     37       Yes      Travel_Rarely       1373  Research & Development
# 23    21        No      Travel_Rarely        391  Research & Development
# 77    45        No      Travel_Rarely        193  Research & Development
# 86    23        No      Travel_Rarely        541                   Sales
# 109   22        No      Travel_Rarely        534  Research & Development
# 127   19       Yes      Travel_Rarely        528                   Sales
# 171   19       Yes  Travel_Frequently        602                   Sales
# 264   28       Yes      Travel_Rarely        529  Research & Development
# 265   29        No      Travel_Rarely       1210                   Sales
# 296   18       Yes      Travel_Rarely        230  Research & Development
#
#      DistanceFromHome  Education    EducationField  EnvironmentSatisfaction  \
# 2                   2          2             Other                        4
# 23                 15          2     Life Sciences                        3
# 77                  6          4             Other                        4
# 86                  2          1  Technical Degree                        3
# 109                15          3           Medical                        2
# 127                22          1         Marketing                        4
# 171                 1          1  Technical Degree                        3
# 264                 2          4     Life Sciences                        1
# 265                 2          3           Medical                        1
# 296                 3          3     Life Sciences                        3
#
#      Gender  ...  PerformanceRating  RelationshipSatisfaction  \
# 2      Male  ...                  3                         2
# 23     Male  ...                  3                         4
# 77     Male  ...                  3                         2
# 86     Male  ...                  3                         3
# 109  Female  ...                  3                         3
# 127    Male  ...                  3                         4
# 171  Female  ...                  4                         1
# 264    Male  ...                  3                         3
# 265    Male  ...                  3                         2
# 296    Male  ...                  3                         3
#
#      StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  \
# 2                   0                 7                      3
# 23                  0                 0                      6
# 77                  0                17                      3
# 86                  1                 3                      3
# 109                 0                 1                      5
# 127                 0                 0                      2
# 171                 0                 1                      5
# 264                 0                 5                      5
# 265                 2                10                      2
# 296                 0                 0                      2
#
#     WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 2                 3               0                   0
# 23                3               0                   0
# 77                4               0                   0
# 86                3               0                   0
# 109               3               0                   0
# 127               2               0                   0
# 171               4               0                   0
# 264               1               0                   0
# 265               3               0                   0
# 296               3               0                   0
#
#      YearsSinceLastPromotion YearsWithCurrManager
# 2                          0                    0
# 23                         0                    0
# 77                         0                    0
# 86                         0                    0
# 109                        0                    0
# 127                        0                    0
# 171                        0                    0
# 264                        0                    0
# 265                        0                    0
# 296                        0                    0
#
# [10 rows x 31 columns]

# %%
df.nlargest(10, "YearsSinceLastPromotion")
# Out:
#      Age Attrition BusinessTravel  DailyRate              Department  \
# 45    41       Yes  Travel_Rarely       1360  Research & Development
# 123   51        No  Travel_Rarely        684  Research & Development
# 126   58       Yes  Travel_Rarely        147  Research & Development
# 178   46        No  Travel_Rarely        526                   Sales
# 237   52        No     Non-Travel        771                   Sales
# 425   50        No  Travel_Rarely       1099  Research & Development
# 701   53        No  Travel_Rarely       1376                   Sales
# 752   36       Yes  Travel_Rarely        885  Research & Development
# 861   46        No  Travel_Rarely       1402                   Sales
# 914   55        No     Non-Travel        177  Research & Development
#
#      DistanceFromHome  Education    EducationField  EnvironmentSatisfaction  \
# 45                 12          3  Technical Degree                        2
# 123                 6          3     Life Sciences                        1
# 126                23          4           Medical                        4
# 178                 1          2         Marketing                        2
# 237                 2          4     Life Sciences                        1
# 425                29          4     Life Sciences                        2
# 701                 2          2           Medical                        3
# 752                16          4     Life Sciences                        3
# 861                 2          3         Marketing                        3
# 914                 8          1           Medical                        4
#
#      Gender  ...  PerformanceRating  RelationshipSatisfaction  \
# 45   Female  ...                  3                         4
# 123    Male  ...                  3                         3
# 126  Female  ...                  3                         4
# 178  Female  ...                  4                         3
# 237    Male  ...                  3                         4
# 425    Male  ...                  3                         2
# 701    Male  ...                  3                         3
# 752  Female  ...                  3                         3
# 861  Female  ...                  4                         1
# 914    Male  ...                  3                         4
#
#      StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  \
# 45                  0                23                      0
# 123                 0                23                      5
# 126                 1                40                      3
# 178                 3                24                      2
# 237                 0                33                      2
# 425                 1                28                      2
# 701                 1                22                      3
# 752                 0                18                      1
# 861                 0                28                      2
# 914                 1                34                      3
#
#     WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 45                3              22                  15
# 123               3              20                  18
# 126               2              40                  10
# 178               3              24                  13
# 237               4              33                   7
# 425               3              27                  10
# 701               4              17                  13
# 752               3              17                  13
# 861               3              26                  15
# 914               3              33                   9
#
#      YearsSinceLastPromotion YearsWithCurrManager
# 45                        15                    8
# 123                       15                   15
# 126                       15                    6
# 178                       15                    7
# 237                       15                   12
# 425                       15                    7
# 701                       15                    2
# 752                       15                   14
# 861                       15                    9
# 914                       15                    0
#
# [10 rows x 31 columns]

# %%
df.nsmallest(10, "YearsSinceLastPromotion")
# Out:
#     Age Attrition BusinessTravel  DailyRate              Department  \
# 0    41       Yes  Travel_Rarely       1102                   Sales
# 2    37       Yes  Travel_Rarely       1373  Research & Development
# 6    59        No  Travel_Rarely       1324  Research & Development
# 7    30        No  Travel_Rarely       1358  Research & Development
# 10   35        No  Travel_Rarely        809  Research & Development
# 11   29        No  Travel_Rarely        153  Research & Development
# 14   28       Yes  Travel_Rarely        103  Research & Development
# 16   32        No  Travel_Rarely        334  Research & Development
# 17   22        No     Non-Travel       1123  Research & Development
# 21   36       Yes  Travel_Rarely       1218                   Sales
#
#     DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                  1          2  Life Sciences                        2
# 2                  2          2          Other                        4
# 6                  3          3        Medical                        3
# 7                 24          1  Life Sciences                        4
# 10                16          3        Medical                        1
# 11                15          2  Life Sciences                        4
# 14                24          3  Life Sciences                        3
# 16                 5          2  Life Sciences                        1
# 17                16          2        Medical                        4
# 21                 9          4  Life Sciences                        3
#
#     Gender  ...  PerformanceRating  RelationshipSatisfaction  \
# 0   Female  ...                  3                         1
# 2     Male  ...                  3                         2
# 6   Female  ...                  4                         1
# 7     Male  ...                  4                         2
# 10    Male  ...                  3                         3
# 11  Female  ...                  3                         4
# 14    Male  ...                  3                         2
# 16    Male  ...                  3                         4
# 17    Male  ...                  3                         2
# 21    Male  ...                  4                         2
#
#     StockOptionLevel TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  \
# 0                  0                 8                      0               1
# 2                  0                 7                      3               3
# 6                  3                12                      3               2
# 7                  1                 1                      2               3
# 10                 1                 6                      5               3
# 11                 0                10                      3               3
# 14                 0                 6                      4               3
# 16                 2                 7                      5               2
# 17                 2                 1                      2               2
# 21                 0                10                      4               3
#
#     YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0                6                   4                        0
# 2                0                   0                        0
# 6                1                   0                        0
# 7                1                   0                        0
# 10               5                   4                        0
# 11               9                   5                        0
# 14               4                   2                        0
# 16               6                   2                        0
# 17               1                   0                        0
# 21               5                   3                        0
#
#    YearsWithCurrManager
# 0                     5
# 2                     0
# 6                     0
# 7                     0
# 10                    3
# 11                    8
# 14                    3
# 16                    5
# 17                    0
# 21                    3
#
# [10 rows x 31 columns]

# %%
df.nlargest(10, "YearsSinceLastPromotion")[["Age", "JobRole", "YearsSinceLastPromotion", "JobLevel"]]
# Out:
#      Age                    JobRole  YearsSinceLastPromotion  JobLevel
# 45    41          Research Director                       15         5
# 123   51          Research Director                       15         5
# 126   58  Healthcare Representative                       15         3
# 178   46            Sales Executive                       15         3
# 237   52                    Manager                       15         5
# 425   50                    Manager                       15         4
# 701   53                    Manager                       15         4
# 752   36      Laboratory Technician                       15         1
# 861   46                    Manager                       15         4
# 914   55  Healthcare Representative                       15         4

# %%
df.nsmallest(10, "YearsSinceLastPromotion")[["Age", "JobRole", "YearsSinceLastPromotion", "JobLevel"]]
# Out:
#     Age                JobRole  YearsSinceLastPromotion  JobLevel
# 0    41        Sales Executive                        0         2
# 2    37  Laboratory Technician                        0         1
# 6    59  Laboratory Technician                        0         1
# 7    30  Laboratory Technician                        0         1
# 10   35  Laboratory Technician                        0         1
# 11   29  Laboratory Technician                        0         2
# 14   28  Laboratory Technician                        0         1
# 16   32     Research Scientist                        0         1
# 17   22  Laboratory Technician                        0         1
# 21   36   Sales Representative                        0         1

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
colunas_categoricas_nao_ordenadas = [
    "BusinessTravel",
    "Department",
    "EducationField",
    "Gender",
    "JobRole",
    "MaritalStatus",
    "OverTime",
]

colunas_categoricas_ordenadas = [
    "Education",
    "EnvironmentSatisfaction",
    "JobSatisfaction",
    "JobInvolvement",
    "JobLevel",
    "PerformanceRating",
    "RelationshipSatisfaction",
    "StockOptionLevel",
    "WorkLifeBalance",
]

coluna_alvo = ["Attrition"]

colunas_numericas = [
    coluna for coluna in df.columns if coluna not in (
        colunas_categoricas_nao_ordenadas + colunas_categoricas_ordenadas + coluna_alvo
    )
]

# %%
colunas_numericas
# Out:
# ['Age',
#  'DailyRate',
#  'DistanceFromHome',
#  'HourlyRate',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'PercentSalaryHike',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
for coluna in (colunas_categoricas_nao_ordenadas + colunas_categoricas_ordenadas):
    print(f"{coluna}: {df[coluna].unique()}")
# Out:
# BusinessTravel: ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# Department: ['Sales' 'Research & Development' 'Human Resources']
# EducationField: ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# Gender: ['Female' 'Male']
# JobRole: ['Sales Executive' 'Research Scientist' 'Laboratory Technician'
#  'Manufacturing Director' 'Healthcare Representative' 'Manager'
#  'Sales Representative' 'Research Director' 'Human Resources']
# MaritalStatus: ['Single' 'Married' 'Divorced']
# OverTime: ['Yes' 'No']
# Education: [2 1 4 3 5]
# EnvironmentSatisfaction: [2 3 4 1]
# JobSatisfaction: [4 2 3 1]
# JobInvolvement: [3 2 4 1]
# JobLevel: [2 1 3 4 5]
# PerformanceRating: [3 4]
# RelationshipSatisfaction: [1 4 2 3]
# StockOptionLevel: [0 1 3 2]
# WorkLifeBalance: [1 3 2 4]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   object
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
#  13  JobRole                   1470 non-null   object
#  14  JobSatisfaction           1470 non-null   int64
#  15  MaritalStatus             1470 non-null   object
#  16  MonthlyIncome             1470 non-null   int64
#  17  MonthlyRate               1470 non-null   int64
#  18  NumCompaniesWorked        1470 non-null   int64
#  19  OverTime                  1470 non-null   object
#  20  PercentSalaryHike         1470 non-null   int64
#  21  PerformanceRating         1470 non-null   int64
#  22  RelationshipSatisfaction  1470 non-null   int64
#  23  StockOptionLevel          1470 non-null   int64
#  24  TotalWorkingYears         1470 non-null   int64
#  25  TrainingTimesLastYear     1470 non-null   int64
#  26  WorkLifeBalance           1470 non-null   int64
#  27  YearsAtCompany            1470 non-null   int64
#  28  YearsInCurrentRole        1470 non-null   int64
#  29  YearsSinceLastPromotion   1470 non-null   int64
#  30  YearsWithCurrManager      1470 non-null   int64
# dtypes: int64(23), object(8)
# memory usage: 356.1+ KB

# %%
for coluna in colunas_categoricas_nao_ordenadas:
    df[coluna] = df[coluna].astype("category")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   category
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   category
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   category
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   category
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
#  13  JobRole                   1470 non-null   category
#  14  JobSatisfaction           1470 non-null   int64
#  15  MaritalStatus             1470 non-null   category
#  16  MonthlyIncome             1470 non-null   int64
#  17  MonthlyRate               1470 non-null   int64
#  18  NumCompaniesWorked        1470 non-null   int64
#  19  OverTime                  1470 non-null   category
#  20  PercentSalaryHike         1470 non-null   int64
#  21  PerformanceRating         1470 non-null   int64
#  22  RelationshipSatisfaction  1470 non-null   int64
#  23  StockOptionLevel          1470 non-null   int64
#  24  TotalWorkingYears         1470 non-null   int64
#  25  TrainingTimesLastYear     1470 non-null   int64
#  26  WorkLifeBalance           1470 non-null   int64
#  27  YearsAtCompany            1470 non-null   int64
#  28  YearsInCurrentRole        1470 non-null   int64
#  29  YearsSinceLastPromotion   1470 non-null   int64
#  30  YearsWithCurrManager      1470 non-null   int64
# dtypes: category(7), int64(23), object(1)
# memory usage: 287.0+ KB

# %%
for coluna in df.select_dtypes(include="category"):
    print(f"{coluna}")
    print(f"{coluna}.cat.categories: {df[coluna].cat.categories}")
    print(f"{coluna}.cat.ordered: {df[coluna].cat.ordered}")
    print(f"{coluna}.cat.codes: {df[coluna].cat.codes.unique()}")
    print()
# Out:
# BusinessTravel
# BusinessTravel.cat.categories: Index(['Non-Travel', 'Travel_Frequently', 'Travel_Rarely'], dtype='object')
# BusinessTravel.cat.ordered: False
# BusinessTravel.cat.codes: [2 1 0]
#
# Department
# Department.cat.categories: Index(['Human Resources', 'Research & Development', 'Sales'], dtype='object')
# Department.cat.ordered: False
# Department.cat.codes: [2 1 0]
#
# EducationField
# EducationField.cat.categories: Index(['Human Resources', 'Life Sciences', 'Marketing', 'Medical', 'Other',
#        'Technical Degree'],
#       dtype='object')
# EducationField.cat.ordered: False
# EducationField.cat.codes: [1 4 3 2 5 0]
#
# Gender
# Gender.cat.categories: Index(['Female', 'Male'], dtype='object')
# Gender.cat.ordered: False
# Gender.cat.codes: [0 1]
#
# JobRole
# JobRole.cat.categories: Index(['Healthcare Representative', 'Human Resources', 'Laboratory Technician',
#        'Manager', 'Manufacturing Director', 'Research Director',
#        'Research Scientist', 'Sales Executive', 'Sales Representative'],
#       dtype='object')
# JobRole.cat.ordered: False
# JobRole.cat.codes: [7 6 2 4 0 3 8 5 1]
#
# MaritalStatus
# MaritalStatus.cat.categories: Index(['Divorced', 'Married', 'Single'], dtype='object')
# MaritalStatus.cat.ordered: False
# MaritalStatus.cat.codes: [2 1 0]
#
# OverTime
# OverTime.cat.categories: Index(['No', 'Yes'], dtype='object')
# OverTime.cat.ordered: False
# OverTime.cat.codes: [1 0]

# %%
df["Attrition"].value_counts().plot(kind="bar");

# %%
df["Attrition"].value_counts().plot(kind="bar", color=["blue", "red"]);

# %%
df["Attrition"].value_counts(normalize=True).plot(kind="bar", color=["blue", "red"]);

# %%
df["Department"].value_counts().plot(kind="bar");

# %%
df.groupby(["Department", "Attrition"]).size()
# Out:
# Department              Attrition
# Human Resources         No            51
#                         Yes           12
# Research & Development  No           828
#                         Yes          133
# Sales                   No           354
#                         Yes           92
# dtype: int64

# %%
df.pivot_table(index="Department", columns="Attrition", aggfunc="size")
# Out:
# Attrition                No  Yes
# Department
# Human Resources          51   12
# Research & Development  828  133
# Sales                   354   92

# %% [markdown]
# O `crosstab` do Pandas é uma função muito útil para criar tabelas de contingência, que são tabelas que resumem a relação entre duas ou mais variáveis. De maneira simplificada, crosstab permite-nos contar quantas vezes cada combinação de valores das variáveis ocorre no dataset. Isso é especialmente útil para análise exploratória de dados, permitindo entender melhor a distribuição e a relação entre variáveis categóricas.

# %%
pd.crosstab(df["Department"], df["Attrition"])
# Out:
# Attrition                No  Yes
# Department
# Human Resources          51   12
# Research & Development  828  133
# Sales                   354   92

# %%
pd.crosstab(df["Department"], df["Attrition"], normalize="index")
# Out:
# Attrition                     No       Yes
# Department
# Human Resources         0.809524  0.190476
# Research & Development  0.861602  0.138398
# Sales                   0.793722  0.206278

# %%
pd.crosstab(df["Department"], df["Attrition"], normalize="columns")
# Out:
# Attrition                     No       Yes
# Department
# Human Resources         0.041363  0.050633
# Research & Development  0.671533  0.561181
# Sales                   0.287105  0.388186

# %% [markdown]
# Colormaps: https://matplotlib.org/stable/users/explain/colors/colormaps.html

# %%
pd.crosstab(df["Department"], df["Attrition"], normalize="index").style.background_gradient(cmap="RdYlGn", axis="columns")
# Out:
# <style type="text/css">
# #T_dfebf_row0_col0, #T_dfebf_row1_col0, #T_dfebf_row2_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_dfebf_row0_col1, #T_dfebf_row1_col1, #T_dfebf_row2_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_dfebf">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_dfebf_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_dfebf_level0_col1" class="col_heading level0 col1" >Yes</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Department</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dfebf_level0_row0" class="row_heading level0 row0" >Human Resources</th>
#       <td id="T_dfebf_row0_col0" class="data row0 col0" >0.809524</td>
#       <td id="T_dfebf_row0_col1" class="data row0 col1" >0.190476</td>
#     </tr>
#     <tr>
#       <th id="T_dfebf_level0_row1" class="row_heading level0 row1" >Research & Development</th>
#       <td id="T_dfebf_row1_col0" class="data row1 col0" >0.861602</td>
#       <td id="T_dfebf_row1_col1" class="data row1 col1" >0.138398</td>
#     </tr>
#     <tr>
#       <th id="T_dfebf_level0_row2" class="row_heading level0 row2" >Sales</th>
#       <td id="T_dfebf_row2_col0" class="data row2 col0" >0.793722</td>
#       <td id="T_dfebf_row2_col1" class="data row2 col1" >0.206278</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.crosstab(df["Department"], df["Attrition"], margins=True, margins_name="Total")
# Out:
# Attrition                 No  Yes  Total
# Department
# Human Resources           51   12     63
# Research & Development   828  133    961
# Sales                    354   92    446
# Total                   1233  237   1470

# %%
pd.crosstab(df["Department"], df["Attrition"]).plot(kind="bar");

# %%
df.groupby("Department")["MonthlyIncome"].mean()
# Out:
# Department
# Human Resources           6654.507937
# Research & Development    6281.252862
# Sales                     6959.172646
# Name: MonthlyIncome, dtype: float64

# %%
df.groupby("Department")["MonthlyIncome"].mean().plot(kind="bar")
# Out:
# <Axes: xlabel='Department'>

# %%
df.groupby(["Department", "Attrition"])["MonthlyIncome"].mean()
# Out:
# Department              Attrition
# Human Resources         No           7345.980392
#                         Yes          3715.750000
# Research & Development  No           6630.326087
#                         Yes          4108.075188
# Sales                   No           7232.240113
#                         Yes          5908.456522
# Name: MonthlyIncome, dtype: float64

# %%
df.pivot_table(index="Department", columns="Attrition", values="MonthlyIncome").style.background_gradient(cmap="RdYlGn", axis="columns")
# Out:
# <style type="text/css">
# #T_53f82_row0_col0, #T_53f82_row1_col0, #T_53f82_row2_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_53f82_row0_col1, #T_53f82_row1_col1, #T_53f82_row2_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_53f82">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_53f82_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_53f82_level0_col1" class="col_heading level0 col1" >Yes</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Department</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_53f82_level0_row0" class="row_heading level0 row0" >Human Resources</th>
#       <td id="T_53f82_row0_col0" class="data row0 col0" >7345.980392</td>
#       <td id="T_53f82_row0_col1" class="data row0 col1" >3715.750000</td>
#     </tr>
#     <tr>
#       <th id="T_53f82_level0_row1" class="row_heading level0 row1" >Research & Development</th>
#       <td id="T_53f82_row1_col0" class="data row1 col0" >6630.326087</td>
#       <td id="T_53f82_row1_col1" class="data row1 col1" >4108.075188</td>
#     </tr>
#     <tr>
#       <th id="T_53f82_level0_row2" class="row_heading level0 row2" >Sales</th>
#       <td id="T_53f82_row2_col0" class="data row2 col0" >7232.240113</td>
#       <td id="T_53f82_row2_col1" class="data row2 col1" >5908.456522</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.pivot_table(index="Department", columns="Attrition", values="MonthlyIncome").plot(kind="bar")
# Out:
# <Axes: xlabel='Department'>

# %%
df.groupby("JobRole")["MonthlyIncome"].mean()
# Out:
# JobRole
# Healthcare Representative     7528.763359
# Human Resources               4235.750000
# Laboratory Technician         3237.169884
# Manager                      17181.676471
# Manufacturing Director        7295.137931
# Research Director            16033.550000
# Research Scientist            3239.972603
# Sales Executive               6924.279141
# Sales Representative          2626.000000
# Name: MonthlyIncome, dtype: float64

# %%
df.groupby(["JobRole", "JobLevel"])["MonthlyIncome"].mean()
# Out:
# JobRole                    JobLevel
# Healthcare Representative  1                    NaN
#                            2            5865.346154
#                            3            9363.954545
#                            4           12973.000000
#                            5                    NaN
# Human Resources            1            2733.212121
#                            2            5563.461538
#                            3            9623.000000
#                            4                    NaN
#                            5                    NaN
# Laboratory Technician      1            2854.590000
#                            2            4455.625000
#                            3            5998.000000
#                            4                    NaN
#                            5                    NaN
# Manager                    1                    NaN
#                            2                    NaN
#                            3           12233.000000
#                            4           16613.276596
#                            5           19183.976744
# Manufacturing Director     1                    NaN
#                            2            5612.755556
#                            3            9307.044444
#                            4           13383.000000
#                            5                    NaN
# Research Director          1                    NaN
#                            2                    NaN
#                            3           12721.571429
#                            4           16429.038462
#                            5           19204.807692
# Research Scientist         1            2827.649573
#                            2            4818.912281
#                            3            9724.000000
#                            4                    NaN
#                            5                    NaN
# Sales Executive            1                    NaN
#                            2            5800.884120
#                            3            9124.987342
#                            4           13202.500000
#                            5                    NaN
# Sales Representative       1            2506.723684
#                            2            3921.000000
#                            3                    NaN
#                            4                    NaN
#                            5                    NaN
# Name: MonthlyIncome, dtype: float64

# %%
df.groupby(["JobRole", "JobLevel"])["MonthlyIncome"].mean().to_frame().style.background_gradient(cmap="RdYlGn", axis="index")
# Out:
# <style type="text/css">
# #T_9c567_row0_col0, #T_9c567_row4_col0, #T_9c567_row8_col0, #T_9c567_row9_col0, #T_9c567_row13_col0, #T_9c567_row14_col0, #T_9c567_row15_col0, #T_9c567_row16_col0, #T_9c567_row20_col0, #T_9c567_row24_col0, #T_9c567_row25_col0, #T_9c567_row26_col0, #T_9c567_row33_col0, #T_9c567_row34_col0, #T_9c567_row35_col0, #T_9c567_row39_col0, #T_9c567_row42_col0, #T_9c567_row43_col0, #T_9c567_row44_col0 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_9c567_row1_col0 {
#   background-color: #f46d43;
#   color: #f1f1f1;
# }
# #T_9c567_row2_col0 {
#   background-color: #fee491;
#   color: #000000;
# }
# #T_9c567_row3_col0 {
#   background-color: #cbe982;
#   color: #000000;
# }
# #T_9c567_row5_col0 {
#   background-color: #ab0626;
#   color: #f1f1f1;
# }
# #T_9c567_row6_col0 {
#   background-color: #ee613e;
#   color: #f1f1f1;
# }
# #T_9c567_row7_col0 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_9c567_row10_col0 {
#   background-color: #af0926;
#   color: #f1f1f1;
# }
# #T_9c567_row11_col0 {
#   background-color: #db382b;
#   color: #f1f1f1;
# }
# #T_9c567_row12_col0 {
#   background-color: #f57245;
#   color: #f1f1f1;
# }
# #T_9c567_row17_col0 {
#   background-color: #dff293;
#   color: #000000;
# }
# #T_9c567_row18_col0 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_9c567_row19_col0, #T_9c567_row29_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_9c567_row21_col0 {
#   background-color: #ef633f;
#   color: #f1f1f1;
# }
# #T_9c567_row22_col0 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_9c567_row23_col0 {
#   background-color: #bfe47a;
#   color: #000000;
# }
# #T_9c567_row27_col0 {
#   background-color: #d3ec87;
#   color: #000000;
# }
# #T_9c567_row28_col0 {
#   background-color: #4bb05c;
#   color: #f1f1f1;
# }
# #T_9c567_row30_col0 {
#   background-color: #ad0826;
#   color: #f1f1f1;
# }
# #T_9c567_row31_col0 {
#   background-color: #e24731;
#   color: #f1f1f1;
# }
# #T_9c567_row32_col0 {
#   background-color: #feea9b;
#   color: #000000;
# }
# #T_9c567_row36_col0 {
#   background-color: #f36b42;
#   color: #f1f1f1;
# }
# #T_9c567_row37_col0 {
#   background-color: #fede89;
#   color: #000000;
# }
# #T_9c567_row38_col0 {
#   background-color: #c5e67e;
#   color: #000000;
# }
# #T_9c567_row40_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_9c567_row41_col0 {
#   background-color: #ce2827;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9c567">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c567_level0_col0" class="col_heading level0 col0" >MonthlyIncome</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >JobRole</th>
#       <th class="index_name level1" >JobLevel</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c567_level0_row0" class="row_heading level0 row0" rowspan="5">Healthcare Representative</th>
#       <th id="T_9c567_level1_row0" class="row_heading level1 row0" >1</th>
#       <td id="T_9c567_row0_col0" class="data row0 col0" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_9c567_level1_row1" class="row_heading level1 row1" >2</th>
#       <td id="T_9c567_row1_col0" class="data row1 col0" >5865.346154</td>
#     </tr>
#     <tr>
#       <th id="T_9c567_level1_row2" class="row_heading level1 row2" >3</th>
#       <td id="T_9c567_row2_col0" class="data row2 col0" >9363.954545</td>
#     </tr>
#     <tr>
#       <th id="T_9c567_level1_row3" class="row_heading level1 row3" >4</th>
#       <td id="T_9c567_row3_col0" class="data row3 col0" >12973.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9c567_level1_row4" class="row_heading level1 row4" >5</th>
#       <td id="T_9c567_row4_col0" class="data row4 col0" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_9c567_level0_row5" class="row_heading level0 row5" rowspan="5">Human Resources</th>
#       <th id="T_9c567_level1_row5" class="row_heading level1 row5" >1</th>
#       <td id="T_9c567_row5_col0" class="data row5 col0" >2733.212121</td>
#     </tr>
#     <tr>
#       <th id="T_9c567_level1_row6" class="row_heading level1 row6" >2</th>
#       <td id="T_9c567_row6_col0" class="data row6 col0" >5563.461538</td>
#     </tr>
#     <tr>
#       <th id="T_9c567_level1_row7" class="row_heading level1 row7" >3</th>
#       <td id="T_9c567_row7_col0" class="data row7 col0" >9623.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9c567_level1_row8" class="row_heading level1 row8" >4</th>
#       <td id="T_9c567_row8_col0" class="data row8 col0" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_9c567_level1_row9" class="row_heading level1 row9" >5</th>
#       <td id="T_9c567_row9_col0" class="data row9 col0" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_9c567_level0_row10" class="row_heading level0 row10" rowspan="5">Laboratory Technician</th>
#       <th id="T_9c567_level1_row10" class="row_heading level1 row10" >1</th>
#       <td id="T_9c567_row10_col0" class="data row10 col0" >2854.590000</td>
#     </tr>
#     <tr>
#       <th id="T_9c567_level1_row11" class="row_heading level1 row11" >2</th>
#       <td id="T_9c567_row11_col0" class="data row11 col0" >4455.625000</td>
#     </tr>
#     <tr>
#       <th id="T_9c567_level1_row12" class="row_heading level1 row12" >3</th>
#       <td id="T_9c567_row12_col0" class="data row12 col0" >5998.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9c567_level1_row13" class="row_heading level1 row13" >4</th>
#       <td id="T_9c567_row13_col0" class="data row13 col0" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_9c567_level1_row14" class="row_heading level1 row14" >5</th>
#       <td id="T_9c567_row14_col0" class="data row14 col0" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_9c567_level0_row15" class="row_heading level0 row15" rowspan="5">Manager</th>
#       <th id="T_9c567_level1_row15" class="row_heading level1 row15" >1</th>
#       <td id="T_9c567_row15_col0" class="data row15 col0" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_9c567_level1_row16" class="row_heading level1 row16" >2</th>
#       <td id="T_9c567_row16_col0" class="data row16 col0" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_9c567_level1_row17" class="row_heading level1 row17" >3</th>
#       <td id="T_9c567_row17_col0" class="data row17 col0" >12233.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9c567_level1_row18" class="row_heading level1 row18" >4</th>
#       <td id="T_9c567_row18_col0" class="data row18 col0" >16613.276596</td>
#     </tr>
#     <tr>
#       <th id="T_9c567_level1_row19" class="row_heading level1 row19" >5</th>
#       <td id="T_9c567_row19_col0" class="data row19 col0" >19183.976744</td>
#     </tr>
#     <tr>
#       <th id="T_9c567_level0_row20" class="row_heading level0 row20" rowspan="5">Manufacturing Director</th>
#       <th id="T_9c567_level1_row20" class="row_heading level1 row20" >1</th>
#       <td id="T_9c567_row20_col0" class="data row20 col0" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_9c567_level1_row21" class="row_heading level1 row21" >2</th>
#       <td id="T_9c567_row21_col0" class="data row21 col0" >5612.755556</td>
#     </tr>
#     <tr>
#       <th id="T_9c567_level1_row22" class="row_heading level1 row22" >3</th>
#       <td id="T_9c567_row22_col0" class="data row22 col0" >9307.044444</td>
#     </tr>
#     <tr>
#       <th id="T_9c567_level1_row23" class="row_heading level1 row23" >4</th>
#       <td id="T_9c567_row23_col0" class="data row23 col0" >13383.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9c567_level1_row24" class="row_heading level1 row24" >5</th>
#       <td id="T_9c567_row24_col0" class="data row24 col0" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_9c567_level0_row25" class="row_heading level0 row25" rowspan="5">Research Director</th>
#       <th id="T_9c567_level1_row25" class="row_heading level1 row25" >1</th>
#       <td id="T_9c567_row25_col0" class="data row25 col0" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_9c567_level1_row26" class="row_heading level1 row26" >2</th>
#       <td id="T_9c567_row26_col0" class="data row26 col0" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_9c567_level1_row27" class="row_heading level1 row27" >3</th>
#       <td id="T_9c567_row27_col0" class="data row27 col0" >12721.571429</td>
#     </tr>
#     <tr>
#       <th i

# %%
df.groupby(["JobRole", "JobLevel", "Attrition"])["MonthlyIncome"].mean()
# Out:
# JobRole                    JobLevel  Attrition
# Healthcare Representative  1         No                   NaN
#                                      Yes                  NaN
#                            2         No           5828.280000
#                                      Yes          6792.000000
#                            3         No           9426.282051
#                                                      ...
# Sales Representative       3         Yes                  NaN
#                            4         No                   NaN
#                                      Yes                  NaN
#                            5         No                   NaN
#                                      Yes                  NaN
# Name: MonthlyIncome, Length: 90, dtype: float64

# %%
df.pivot_table(index=["JobRole", "JobLevel"], columns="Attrition", values="MonthlyIncome")
# Out:
# Attrition                                     No           Yes
# JobRole                   JobLevel
# Healthcare Representative 2          5828.280000   6792.000000
#                           3          9426.282051   8877.800000
#                           4         13073.500000  12169.000000
# Human Resources           1          2871.260870   2415.700000
#                           2          5563.461538           NaN
#                           3          9326.500000  10216.000000
# Laboratory Technician     1          2921.708333   2682.000000
#                           2          4394.000000   5084.200000
#                           3          6306.500000   5381.000000
# Manager                   3         12133.700000  12729.500000
#                           4         16613.276596           NaN
#                           5         19159.575000  19509.333333
# Manufacturing Director    2          5644.870588   5066.800000
#                           3          9262.400000   9664.200000
#                           4         13383.000000           NaN
# Research Director         3         12721.571429           NaN
#                           4         16429.038462           NaN
#                           5         19188.916667  19395.500000
# Research Scientist        1          2859.455026   2694.066667
#                           2          4822.345455   4724.500000
#                           3          9724.000000           NaN
# Sales Executive           2          5760.218274   6023.416667
#                           3          9103.661290   9202.764706
#                           4         13125.200000  13395.750000
# Sales Representative      1          2603.659091   2373.437500
#                           2          4226.833333   2086.000000

# %%
df.pivot_table(
    index=["JobRole", "JobLevel"], 
    columns="Attrition", 
    values="MonthlyIncome"
).style.background_gradient(cmap="RdYlGn", axis="columns")
# Out:
# <style type="text/css">
# #T_97015_row0_col0, #T_97015_row1_col1, #T_97015_row2_col1, #T_97015_row3_col1, #T_97015_row4_col0, #T_97015_row4_col1, #T_97015_row5_col0, #T_97015_row6_col1, #T_97015_row7_col0, #T_97015_row8_col1, #T_97015_row9_col0, #T_97015_row10_col0, #T_97015_row10_col1, #T_97015_row11_col0, #T_97015_row12_col1, #T_97015_row13_col0, #T_97015_row14_col0, #T_97015_row14_col1, #T_97015_row15_col0, #T_97015_row15_col1, #T_97015_row16_col0, #T_97015_row16_col1, #T_97015_row17_col0, #T_97015_row18_col1, #T_97015_row19_col1, #T_97015_row20_col0, #T_97015_row20_col1, #T_97015_row21_col0, #T_97015_row22_col0, #T_97015_row23_col0, #T_97015_row24_col1, #T_97015_row25_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_97015_row0_col1, #T_97015_row1_col0, #T_97015_row2_col0, #T_97015_row3_col0, #T_97015_row5_col1, #T_97015_row6_col0, #T_97015_row7_col1, #T_97015_row8_col0, #T_97015_row9_col1, #T_97015_row11_col1, #T_97015_row12_col0, #T_97015_row13_col1, #T_97015_row17_col1, #T_97015_row18_col0, #T_97015_row19_col0, #T_97015_row21_col1, #T_97015_row22_col1, #T_97015_row23_col1, #T_97015_row24_col0, #T_97015_row25_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_97015">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_97015_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_97015_level0_col1" class="col_heading level0 col1" >Yes</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >JobRole</th>
#       <th class="index_name level1" >JobLevel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_97015_level0_row0" class="row_heading level0 row0" rowspan="3">Healthcare Representative</th>
#       <th id="T_97015_level1_row0" class="row_heading level1 row0" >2</th>
#       <td id="T_97015_row0_col0" class="data row0 col0" >5828.280000</td>
#       <td id="T_97015_row0_col1" class="data row0 col1" >6792.000000</td>
#     </tr>
#     <tr>
#       <th id="T_97015_level1_row1" class="row_heading level1 row1" >3</th>
#       <td id="T_97015_row1_col0" class="data row1 col0" >9426.282051</td>
#       <td id="T_97015_row1_col1" class="data row1 col1" >8877.800000</td>
#     </tr>
#     <tr>
#       <th id="T_97015_level1_row2" class="row_heading level1 row2" >4</th>
#       <td id="T_97015_row2_col0" class="data row2 col0" >13073.500000</td>
#       <td id="T_97015_row2_col1" class="data row2 col1" >12169.000000</td>
#     </tr>
#     <tr>
#       <th id="T_97015_level0_row3" class="row_heading level0 row3" rowspan="3">Human Resources</th>
#       <th id="T_97015_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_97015_row3_col0" class="data row3 col0" >2871.260870</td>
#       <td id="T_97015_row3_col1" class="data row3 col1" >2415.700000</td>
#     </tr>
#     <tr>
#       <th id="T_97015_level1_row4" class="row_heading level1 row4" >2</th>
#       <td id="T_97015_row4_col0" class="data row4 col0" >5563.461538</td>
#       <td id="T_97015_row4_col1" class="data row4 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_97015_level1_row5" class="row_heading level1 row5" >3</th>
#       <td id="T_97015_row5_col0" class="data row5 col0" >9326.500000</td>
#       <td id="T_97015_row5_col1" class="data row5 col1" >10216.000000</td>
#     </tr>
#     <tr>
#       <th id="T_97015_level0_row6" class="row_heading level0 row6" rowspan="3">Laboratory Technician</th>
#       <th id="T_97015_level1_row6" class="row_heading level1 row6" >1</th>
#       <td id="T_97015_row6_col0" class="data row6 col0" >2921.708333</td>
#       <td id="T_97015_row6_col1" class="data row6 col1" >2682.000000</td>
#     </tr>
#     <tr>
#       <th id="T_97015_level1_row7" class="row_heading level1 row7" >2</th>
#       <td id="T_97015_row7_col0" class="data row7 col0" >4394.000000</td>
#       <td id="T_97015_row7_col1" class="data row7 col1" >5084.200000</td>
#     </tr>
#     <tr>
#       <th id="T_97015_level1_row8" class="row_heading level1 row8" >3</th>
#       <td id="T_97015_row8_col0" class="data row8 col0" >6306.500000</td>
#       <td id="T_97015_row8_col1" class="data row8 col1" >5381.000000</td>
#     </tr>
#     <tr>
#       <th id="T_97015_level0_row9" class="row_heading level0 row9" rowspan="3">Manager</th>
#       <th id="T_97015_level1_row9" class="row_heading level1 row9" >3</th>
#       <td id="T_97015_row9_col0" class="data row9 col0" >12133.700000</td>
#       <td id="T_97015_row9_col1" class="data row9 col1" >12729.500000</td>
#     </tr>
#     <tr>
#       <th id="T_97015_level1_row10" class="row_heading level1 row10" >4</th>
#       <td id="T_97015_row10_col0" class="data row10 col0" >16613.276596</td>
#       <td id="T_97015_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_97015_level1_row11" class="row_heading level1 row11" >5</th>
#       <td id="T_97015_row11_col0" class="data row11 col0" >19159.575000</td>
#       <td id="T_97015_row11_col1" class="data row11 col1" >19509.333333</td>
#     </tr>
#     <tr>
#       <th id="T_97015_level0_row12" class="row_heading level0 row12" rowspan="3">Manufacturing Director</th>
#       <th id="T_97015_level1_row12" class="row_heading level1 row12" >2</th>
#       <td id="T_97015_row12_col0" class="data row12 col0" >5644.870588</td>
#       <td id="T_97015_row12_col1" class="data row12 col1" >5066.800000</td>
#     </tr>
#     <tr>
#       <th id="T_97015_level1_row13" class="row_heading level1 row13" >3</th>
#       <td id="T_97015_row13_col0" class="data row13 col0" >9262.400000</td>
#       <td id="T_97015_row13_col1" class="data row13 col1" >9664.200000</td>
#     </tr>
#     <tr>
#       <th id="T_97015_level1_row14" class="row_heading level1 row14" >4</th>
#       <td id="T_97015_row14_col0" class="data row14 col0" >13383.000000</td>
#       <td id="T_97015_row14_col1" class="data row14 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_97015_level0_row15" class="row_heading level0 row15" rowspan="3">Research Director</th>
#       <th id="T_97015_level1_row15" class="row_heading level1 row15" >3</th>
#       <td id="T_97015_row15_col0" class="data row15 col0" >12721.571429</td>
#       <td id="T_97015_row15_col1" class="data row15 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_97015_level1_row16" class="row_heading level1 row16" >4</th>
#       <td id="T_97015_row16_col0" class="data row16 col0" >16429.038462</td>
#       <td id="T_97015_row16_col1" class="data row16 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_97015_level1_row17" class="row_heading level1 row17" >5</th>
#       <td id="T_97015_row17_col0" class="data row17 col0" >19188.916667</td>
#       <td id="T_97015_row17_col1" class="data row17 col1" >19395.500000</td>
#     </tr>
#     <tr>
#       <th id="T_97015_level0_row18" class="row_heading level0 row18" rowspan="3">Research Scientist</th>
#       <th id="T_97015_level1_row18" class="row_heading level1 row18" >1</th>
#       <td id="T_97015_row18_col0" class="data row18 col0" >2859.455026</td>
#       <td id="T_97015_row18_col1" class="data row18 col1" >2694.066667</td>
#     </tr>
#     <tr>
#       <th id="T_97015_level1_row19" class="row_heading level1 row19" >2</th>
#       <td id="T_97015_row19_col0" class="data row19 col0" >4822.345455</td>
#       <td id="T_97015_row19_col1" class="data row19 col1" >4724.500000</td>
#     </tr>
#     <tr>
#       <th id="T_97015_level1_row20" class="row_heading level1 row20" >3</th>
#       <td id="T_97015_row20_col0" class="data row20 col0" >9724.000000</td>
#       <td id="T_97015_row20_col1" class="data row20 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_97015_level0_row21" class="row_heading level0 row21" rowspan="3">Sales Executive</th>
#       <th id="T_97015_level1_row21" class="row_heading level1 row21" >2</th>
#       <td id="T_97015_row21_col0" class="data row21 col0" >5760.218274</td>
#       <td id="T_97015_row21_col1" class="data row21 col1" >6023.416667</td>
#     </tr>
#     <tr>
#       <th id="T_97015_level1_row22" class="row_heading level1 row22" >3</th>

# %%
df.pivot_table(
    index=["JobRole", "JobLevel"], 
    columns="Attrition", 
    values="MonthlyIncome",
    aggfunc=["mean", "size"]
)
# Out:
#                                             mean               size
# Attrition                                     No           Yes   No Yes
# JobRole                   JobLevel
# Healthcare Representative 2          5828.280000   6792.000000   75   3
#                           3          9426.282051   8877.800000   39   5
#                           4         13073.500000  12169.000000    8   1
# Human Resources           1          2871.260870   2415.700000   23  10
#                           2          5563.461538           NaN   13   0
#                           3          9326.500000  10216.000000    4   2
# Laboratory Technician     1          2921.708333   2682.000000  144  56
#                           2          4394.000000   5084.200000   51   5
#                           3          6306.500000   5381.000000    2   1
# Manager                   3         12133.700000  12729.500000   10   2
#                           4         16613.276596           NaN   47   0
#                           5         19159.575000  19509.333333   40   3
# Manufacturing Director    2          5644.870588   5066.800000   85   5
#                           3          9262.400000   9664.200000   40   5
#                           4         13383.000000           NaN   10   0
# Research Director         3         12721.571429           NaN   28   0
#                           4         16429.038462           NaN   26   0
#                           5         19188.916667  19395.500000   24   2
# Research Scientist        1          2859.455026   2694.066667  189  45
#                           2          4822.345455   4724.500000   55   2
#                           3          9724.000000           NaN    1   0
# Sales Executive           2          5760.218274   6023.416667  197  36
#                           3          9103.661290   9202.764706   62  17
#                           4         13125.200000  13395.750000   10   4
# Sales Representative      1          2603.659091   2373.437500   44  32
#                           2          4226.833333   2086.000000    6   1
# Healthcare Representative 1                  NaN           NaN    0   0
#                           5                  NaN           NaN    0   0
# Human Resources           4                  NaN           NaN    0   0
#                           5                  NaN           NaN    0   0
# Laboratory Technician     4                  NaN           NaN    0   0
#                           5                  NaN           NaN    0   0
# Manager                   1                  NaN           NaN    0   0
#                           2                  NaN           NaN    0   0
# Manufacturing Director    1                  NaN           NaN    0   0
#                           5                  NaN           NaN    0   0
# Research Director         1                  NaN           NaN    0   0
#                           2                  NaN           NaN    0   0
# Research Scientist        4                  NaN           NaN    0   0
#                           5                  NaN           NaN    0   0
# Sales Executive           1                  NaN           NaN    0   0
#                           5                  NaN           NaN    0   0
# Sales Representative      3                  NaN           NaN    0   0
#                           4                  NaN           NaN    0   0
#                           5                  NaN           NaN    0   0

# %%
df.pivot_table(
    index=["JobRole", "JobLevel"], 
    columns="Attrition", 
    values="MonthlyIncome",
    aggfunc=["mean", "size"]
).dropna(how="all", subset=[("mean", "No"), ("mean", "Yes")])
# Out:
#                                             mean               size
# Attrition                                     No           Yes   No Yes
# JobRole                   JobLevel
# Healthcare Representative 2          5828.280000   6792.000000   75   3
#                           3          9426.282051   8877.800000   39   5
#                           4         13073.500000  12169.000000    8   1
# Human Resources           1          2871.260870   2415.700000   23  10
#                           2          5563.461538           NaN   13   0
#                           3          9326.500000  10216.000000    4   2
# Laboratory Technician     1          2921.708333   2682.000000  144  56
#                           2          4394.000000   5084.200000   51   5
#                           3          6306.500000   5381.000000    2   1
# Manager                   3         12133.700000  12729.500000   10   2
#                           4         16613.276596           NaN   47   0
#                           5         19159.575000  19509.333333   40   3
# Manufacturing Director    2          5644.870588   5066.800000   85   5
#                           3          9262.400000   9664.200000   40   5
#                           4         13383.000000           NaN   10   0
# Research Director         3         12721.571429           NaN   28   0
#                           4         16429.038462           NaN   26   0
#                           5         19188.916667  19395.500000   24   2
# Research Scientist        1          2859.455026   2694.066667  189  45
#                           2          4822.345455   4724.500000   55   2
#                           3          9724.000000           NaN    1   0
# Sales Executive           2          5760.218274   6023.416667  197  36
#                           3          9103.661290   9202.764706   62  17
#                           4         13125.200000  13395.750000   10   4
# Sales Representative      1          2603.659091   2373.437500   44  32
#                           2          4226.833333   2086.000000    6   1

# %%
df.pivot_table(
    index=["JobRole", "JobLevel"], 
    columns="Attrition", 
    values="MonthlyIncome",
    aggfunc=["size"]
)
# Out:
#                                    size
# Attrition                            No Yes
# JobRole                   JobLevel
# Healthcare Representative 1           0   0
#                           2          75   3
#                           3          39   5
#                           4           8   1
#                           5           0   0
# Human Resources           1          23  10
#                           2          13   0
#                           3           4   2
#                           4           0   0
#                           5           0   0
# Laboratory Technician     1         144  56
#                           2          51   5
#                           3           2   1
#                           4           0   0
#                           5           0   0
# Manager                   1           0   0
#                           2           0   0
#                           3          10   2
#                           4          47   0
#                           5          40   3
# Manufacturing Director    1           0   0
#                           2          85   5
#                           3          40   5
#                           4          10   0
#                           5           0   0
# Research Director         1           0   0
#                           2           0   0
#                           3          28   0
#                           4          26   0
#                           5          24   2
# Research Scientist        1         189  45
#                           2          55   2
#                           3           1   0
#                           4           0   0
#                           5           0   0
# Sales Executive           1           0   0
#                           2         197  36
#                           3          62  17
#                           4          10   4
#                           5           0   0
# Sales Representative      1          44  32
#                           2           6   1
#                           3           0   0
#                           4           0   0
#                           5           0   0

# %%
pd.crosstab([df["JobRole"], df["JobLevel"]], df["Attrition"])
# Out:
# Attrition                            No  Yes
# JobRole                   JobLevel
# Healthcare Representative 2          75    3
#                           3          39    5
#                           4           8    1
# Human Resources           1          23   10
#                           2          13    0
#                           3           4    2
# Laboratory Technician     1         144   56
#                           2          51    5
#                           3           2    1
# Manager                   3          10    2
#                           4          47    0
#                           5          40    3
# Manufacturing Director    2          85    5
#                           3          40    5
#                           4          10    0
# Research Director         3          28    0
#                           4          26    0
#                           5          24    2
# Research Scientist        1         189   45
#                           2          55    2
#                           3           1    0
# Sales Executive           2         197   36
#                           3          62   17
#                           4          10    4
# Sales Representative      1          44   32
#                           2           6    1

# %%
pd.crosstab(
    [df["JobRole"], df["JobLevel"]], 
    df["Attrition"], 
    normalize="index"
).style.background_gradient(cmap="RdYlGn", axis="columns")
# Out:
# <style type="text/css">
# #T_36f98_row0_col0, #T_36f98_row1_col0, #T_36f98_row2_col0, #T_36f98_row3_col0, #T_36f98_row4_col0, #T_36f98_row5_col0, #T_36f98_row6_col0, #T_36f98_row7_col0, #T_36f98_row8_col0, #T_36f98_row9_col0, #T_36f98_row10_col0, #T_36f98_row11_col0, #T_36f98_row12_col0, #T_36f98_row13_col0, #T_36f98_row14_col0, #T_36f98_row15_col0, #T_36f98_row16_col0, #T_36f98_row17_col0, #T_36f98_row18_col0, #T_36f98_row19_col0, #T_36f98_row20_col0, #T_36f98_row21_col0, #T_36f98_row22_col0, #T_36f98_row23_col0, #T_36f98_row24_col0, #T_36f98_row25_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_36f98_row0_col1, #T_36f98_row1_col1, #T_36f98_row2_col1, #T_36f98_row3_col1, #T_36f98_row4_col1, #T_36f98_row5_col1, #T_36f98_row6_col1, #T_36f98_row7_col1, #T_36f98_row8_col1, #T_36f98_row9_col1, #T_36f98_row10_col1, #T_36f98_row11_col1, #T_36f98_row12_col1, #T_36f98_row13_col1, #T_36f98_row14_col1, #T_36f98_row15_col1, #T_36f98_row16_col1, #T_36f98_row17_col1, #T_36f98_row18_col1, #T_36f98_row19_col1, #T_36f98_row20_col1, #T_36f98_row21_col1, #T_36f98_row22_col1, #T_36f98_row23_col1, #T_36f98_row24_col1, #T_36f98_row25_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_36f98">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_36f98_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_36f98_level0_col1" class="col_heading level0 col1" >Yes</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >JobRole</th>
#       <th class="index_name level1" >JobLevel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_36f98_level0_row0" class="row_heading level0 row0" rowspan="3">Healthcare Representative</th>
#       <th id="T_36f98_level1_row0" class="row_heading level1 row0" >2</th>
#       <td id="T_36f98_row0_col0" class="data row0 col0" >0.961538</td>
#       <td id="T_36f98_row0_col1" class="data row0 col1" >0.038462</td>
#     </tr>
#     <tr>
#       <th id="T_36f98_level1_row1" class="row_heading level1 row1" >3</th>
#       <td id="T_36f98_row1_col0" class="data row1 col0" >0.886364</td>
#       <td id="T_36f98_row1_col1" class="data row1 col1" >0.113636</td>
#     </tr>
#     <tr>
#       <th id="T_36f98_level1_row2" class="row_heading level1 row2" >4</th>
#       <td id="T_36f98_row2_col0" class="data row2 col0" >0.888889</td>
#       <td id="T_36f98_row2_col1" class="data row2 col1" >0.111111</td>
#     </tr>
#     <tr>
#       <th id="T_36f98_level0_row3" class="row_heading level0 row3" rowspan="3">Human Resources</th>
#       <th id="T_36f98_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_36f98_row3_col0" class="data row3 col0" >0.696970</td>
#       <td id="T_36f98_row3_col1" class="data row3 col1" >0.303030</td>
#     </tr>
#     <tr>
#       <th id="T_36f98_level1_row4" class="row_heading level1 row4" >2</th>
#       <td id="T_36f98_row4_col0" class="data row4 col0" >1.000000</td>
#       <td id="T_36f98_row4_col1" class="data row4 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_36f98_level1_row5" class="row_heading level1 row5" >3</th>
#       <td id="T_36f98_row5_col0" class="data row5 col0" >0.666667</td>
#       <td id="T_36f98_row5_col1" class="data row5 col1" >0.333333</td>
#     </tr>
#     <tr>
#       <th id="T_36f98_level0_row6" class="row_heading level0 row6" rowspan="3">Laboratory Technician</th>
#       <th id="T_36f98_level1_row6" class="row_heading level1 row6" >1</th>
#       <td id="T_36f98_row6_col0" class="data row6 col0" >0.720000</td>
#       <td id="T_36f98_row6_col1" class="data row6 col1" >0.280000</td>
#     </tr>
#     <tr>
#       <th id="T_36f98_level1_row7" class="row_heading level1 row7" >2</th>
#       <td id="T_36f98_row7_col0" class="data row7 col0" >0.910714</td>
#       <td id="T_36f98_row7_col1" class="data row7 col1" >0.089286</td>
#     </tr>
#     <tr>
#       <th id="T_36f98_level1_row8" class="row_heading level1 row8" >3</th>
#       <td id="T_36f98_row8_col0" class="data row8 col0" >0.666667</td>
#       <td id="T_36f98_row8_col1" class="data row8 col1" >0.333333</td>
#     </tr>
#     <tr>
#       <th id="T_36f98_level0_row9" class="row_heading level0 row9" rowspan="3">Manager</th>
#       <th id="T_36f98_level1_row9" class="row_heading level1 row9" >3</th>
#       <td id="T_36f98_row9_col0" class="data row9 col0" >0.833333</td>
#       <td id="T_36f98_row9_col1" class="data row9 col1" >0.166667</td>
#     </tr>
#     <tr>
#       <th id="T_36f98_level1_row10" class="row_heading level1 row10" >4</th>
#       <td id="T_36f98_row10_col0" class="data row10 col0" >1.000000</td>
#       <td id="T_36f98_row10_col1" class="data row10 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_36f98_level1_row11" class="row_heading level1 row11" >5</th>
#       <td id="T_36f98_row11_col0" class="data row11 col0" >0.930233</td>
#       <td id="T_36f98_row11_col1" class="data row11 col1" >0.069767</td>
#     </tr>
#     <tr>
#       <th id="T_36f98_level0_row12" class="row_heading level0 row12" rowspan="3">Manufacturing Director</th>
#       <th id="T_36f98_level1_row12" class="row_heading level1 row12" >2</th>
#       <td id="T_36f98_row12_col0" class="data row12 col0" >0.944444</td>
#       <td id="T_36f98_row12_col1" class="data row12 col1" >0.055556</td>
#     </tr>
#     <tr>
#       <th id="T_36f98_level1_row13" class="row_heading level1 row13" >3</th>
#       <td id="T_36f98_row13_col0" class="data row13 col0" >0.888889</td>
#       <td id="T_36f98_row13_col1" class="data row13 col1" >0.111111</td>
#     </tr>
#     <tr>
#       <th id="T_36f98_level1_row14" class="row_heading level1 row14" >4</th>
#       <td id="T_36f98_row14_col0" class="data row14 col0" >1.000000</td>
#       <td id="T_36f98_row14_col1" class="data row14 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_36f98_level0_row15" class="row_heading level0 row15" rowspan="3">Research Director</th>
#       <th id="T_36f98_level1_row15" class="row_heading level1 row15" >3</th>
#       <td id="T_36f98_row15_col0" class="data row15 col0" >1.000000</td>
#       <td id="T_36f98_row15_col1" class="data row15 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_36f98_level1_row16" class="row_heading level1 row16" >4</th>
#       <td id="T_36f98_row16_col0" class="data row16 col0" >1.000000</td>
#       <td id="T_36f98_row16_col1" class="data row16 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_36f98_level1_row17" class="row_heading level1 row17" >5</th>
#       <td id="T_36f98_row17_col0" class="data row17 col0" >0.923077</td>
#       <td id="T_36f98_row17_col1" class="data row17 col1" >0.076923</td>
#     </tr>
#     <tr>
#       <th id="T_36f98_level0_row18" class="row_heading level0 row18" rowspan="3">Research Scientist</th>
#       <th id="T_36f98_level1_row18" class="row_heading level1 row18" >1</th>
#       <td id="T_36f98_row18_col0" class="data row18 col0" >0.807692</td>
#       <td id="T_36f98_row18_col1" class="data row18 col1" >0.192308</td>
#     </tr>
#     <tr>
#       <th id="T_36f98_level1_row19" class="row_heading level1 row19" >2</th>
#       <td id="T_36f98_row19_col0" class="data row19 col0" >0.964912</td>
#       <td id="T_36f98_row19_col1" class="data row19 col1" >0.035088</td>
#     </tr>
#     <tr>
#       <th id="T_36f98_level1_row20" class="row_heading level1 row20" >3</th>
#       <td id="T_36f98_row20_col0" class="data row20 col0" >1.000000</td>
#       <td id="T_36f98_row20_col1" class="data row20 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_36f98_level0_row21" class="row_heading level0 row21" rowspan="3">Sales Executive</th>
#       <th id="T_36f98_level1_row21" class="row_heading level1 row21" >2</th>
#       <td id="T_36f98_row21_col0" class="data row21 col0" >0.845494</td>
#       <td id="T_36f98_row21_col1" class="data row21 col1" >0.154506</td>
#     </tr>
#     <tr>
#       <th id="T_36f98_level1_row22" class="row_heading level1 row22" >3</th>
#       <td id="T_36f98_row22_col0" class="data row22 col0" >0.784810</td>
#       <td id="T_36f98_row22

# %%
pd.crosstab(
    [df["JobRole"], df["JobLevel"]], 
    df["Attrition"], 
    normalize="index"
).style.background_gradient(cmap="RdYlGn", axis="columns", vmin=0, vmax=1)
# Out:
# <style type="text/css">
# #T_476eb_row0_col0 {
#   background-color: #097940;
#   color: #f1f1f1;
# }
# #T_476eb_row0_col1 {
#   background-color: #b71126;
#   color: #f1f1f1;
# }
# #T_476eb_row1_col0 {
#   background-color: #249d53;
#   color: #f1f1f1;
# }
# #T_476eb_row1_col1 {
#   background-color: #db382b;
#   color: #f1f1f1;
# }
# #T_476eb_row2_col0, #T_476eb_row13_col0 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_476eb_row2_col1, #T_476eb_row13_col1 {
#   background-color: #da362a;
#   color: #f1f1f1;
# }
# #T_476eb_row3_col0 {
#   background-color: #a7d96b;
#   color: #000000;
# }
# #T_476eb_row3_col1 {
#   background-color: #fdaf62;
#   color: #000000;
# }
# #T_476eb_row4_col0, #T_476eb_row10_col0, #T_476eb_row14_col0, #T_476eb_row15_col0, #T_476eb_row16_col0, #T_476eb_row20_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_476eb_row4_col1, #T_476eb_row10_col1, #T_476eb_row14_col1, #T_476eb_row15_col1, #T_476eb_row16_col1, #T_476eb_row20_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_476eb_row5_col0, #T_476eb_row8_col0 {
#   background-color: #b7e075;
#   color: #000000;
# }
# #T_476eb_row5_col1, #T_476eb_row8_col1 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_476eb_row6_col0 {
#   background-color: #98d368;
#   color: #000000;
# }
# #T_476eb_row6_col1 {
#   background-color: #fba05b;
#   color: #000000;
# }
# #T_476eb_row7_col0 {
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_476eb_row7_col1 {
#   background-color: #d02927;
#   color: #f1f1f1;
# }
# #T_476eb_row9_col0 {
#   background-color: #4bb05c;
#   color: #f1f1f1;
# }
# #T_476eb_row9_col1 {
#   background-color: #ea5739;
#   color: #f1f1f1;
# }
# #T_476eb_row11_col0 {
#   background-color: #118848;
#   color: #f1f1f1;
# }
# #T_476eb_row11_col1 {
#   background-color: #c62027;
#   color: #f1f1f1;
# }
# #T_476eb_row12_col0 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_476eb_row12_col1 {
#   background-color: #c01a27;
#   color: #f1f1f1;
# }
# #T_476eb_row17_col0 {
#   background-color: #138c4a;
#   color: #f1f1f1;
# }
# #T_476eb_row17_col1 {
#   background-color: #ca2427;
#   color: #f1f1f1;
# }
# #T_476eb_row18_col0 {
#   background-color: #60ba62;
#   color: #f1f1f1;
# }
# #T_476eb_row18_col1 {
#   background-color: #f26841;
#   color: #f1f1f1;
# }
# #T_476eb_row19_col0 {
#   background-color: #08773f;
#   color: #f1f1f1;
# }
# #T_476eb_row19_col1 {
#   background-color: #b50f26;
#   color: #f1f1f1;
# }
# #T_476eb_row21_col0 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_476eb_row21_col1 {
#   background-color: #e65036;
#   color: #f1f1f1;
# }
# #T_476eb_row22_col0 {
#   background-color: #70c164;
#   color: #000000;
# }
# #T_476eb_row22_col1 {
#   background-color: #f57748;
#   color: #f1f1f1;
# }
# #T_476eb_row23_col0 {
#   background-color: #9dd569;
#   color: #000000;
# }
# #T_476eb_row23_col1 {
#   background-color: #fca55d;
#   color: #000000;
# }
# #T_476eb_row24_col0 {
#   background-color: #e0f295;
#   color: #000000;
# }
# #T_476eb_row24_col1 {
#   background-color: #fee695;
#   color: #000000;
# }
# #T_476eb_row25_col0 {
#   background-color: #39a758;
#   color: #f1f1f1;
# }
# #T_476eb_row25_col1 {
#   background-color: #e34933;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_476eb">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_476eb_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_476eb_level0_col1" class="col_heading level0 col1" >Yes</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >JobRole</th>
#       <th class="index_name level1" >JobLevel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_476eb_level0_row0" class="row_heading level0 row0" rowspan="3">Healthcare Representative</th>
#       <th id="T_476eb_level1_row0" class="row_heading level1 row0" >2</th>
#       <td id="T_476eb_row0_col0" class="data row0 col0" >0.961538</td>
#       <td id="T_476eb_row0_col1" class="data row0 col1" >0.038462</td>
#     </tr>
#     <tr>
#       <th id="T_476eb_level1_row1" class="row_heading level1 row1" >3</th>
#       <td id="T_476eb_row1_col0" class="data row1 col0" >0.886364</td>
#       <td id="T_476eb_row1_col1" class="data row1 col1" >0.113636</td>
#     </tr>
#     <tr>
#       <th id="T_476eb_level1_row2" class="row_heading level1 row2" >4</th>
#       <td id="T_476eb_row2_col0" class="data row2 col0" >0.888889</td>
#       <td id="T_476eb_row2_col1" class="data row2 col1" >0.111111</td>
#     </tr>
#     <tr>
#       <th id="T_476eb_level0_row3" class="row_heading level0 row3" rowspan="3">Human Resources</th>
#       <th id="T_476eb_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_476eb_row3_col0" class="data row3 col0" >0.696970</td>
#       <td id="T_476eb_row3_col1" class="data row3 col1" >0.303030</td>
#     </tr>
#     <tr>
#       <th id="T_476eb_level1_row4" class="row_heading level1 row4" >2</th>
#       <td id="T_476eb_row4_col0" class="data row4 col0" >1.000000</td>
#       <td id="T_476eb_row4_col1" class="data row4 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_476eb_level1_row5" class="row_heading level1 row5" >3</th>
#       <td id="T_476eb_row5_col0" class="data row5 col0" >0.666667</td>
#       <td id="T_476eb_row5_col1" class="data row5 col1" >0.333333</td>
#     </tr>
#     <tr>
#       <th id="T_476eb_level0_row6" class="row_heading level0 row6" rowspan="3">Laboratory Technician</th>
#       <th id="T_476eb_level1_row6" class="row_heading level1 row6" >1</th>
#       <td id="T_476eb_row6_col0" class="data row6 col0" >0.720000</td>
#       <td id="T_476eb_row6_col1" class="data row6 col1" >0.280000</td>
#     </tr>
#     <tr>
#       <th id="T_476eb_level1_row7" class="row_heading level1 row7" >2</th>
#       <td id="T_476eb_row7_col0" class="data row7 col0" >0.910714</td>
#       <td id="T_476eb_row7_col1" class="data row7 col1" >0.089286</td>
#     </tr>
#     <tr>
#       <th id="T_476eb_level1_row8" class="row_heading level1 row8" >3</th>
#       <td id="T_476eb_row8_col0" class="data row8 col0" >0.666667</td>
#       <td id="T_476eb_row8_col1" class="data row8 col1" >0.333333</td>
#     </tr>
#     <tr>
#       <th id="T_476eb_level0_row9" class="row_heading level0 row9" rowspan="3">Manager</th>
#       <th id="T_476eb_level1_row9" class="row_heading level1 row9" >3</th>
#       <td id="T_476eb_row9_col0" class="data row9 col0" >0.833333</td>
#       <td id="T_476eb_row9_col1" class="data row9 col1" >0.166667</td>
#     </tr>
#     <tr>
#       <th id="T_476eb_level1_row10" class="row_heading level1 row10" >4</th>
#       <td id="T_476eb_row10_col0" class="data row10 col0" >1.000000</td>
#       <td id="T_476eb_row10_col1" class="data row10 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_476eb_level1_row11" class="row_heading level1 row11" >5</th>
#       <td id="T_476eb_row11_col0" class="data row11 col0" >0.930233</td>
#       <td id="T_476eb_row11_col1" class="data row11 col1" >0.069767</td>
#     </tr>
#     <tr>
#       <th id="T_476eb_level0_row12" class="row_heading level0 row12" rowspan="3">Manufacturing Director</th>
#       <th id="T_476eb_level1_row12" class="row_heading level1 row12" >2</th>
#       <td id="T_476eb_row12_col0" class="data row12 col0" >0.944444</td>
#       <td id="T_476eb_row12_col1" class="data row12 col1" >0.055556</td>
#     </tr>
#     <tr>
#       <th id="T_476eb_level1_row13" class="row_heading level1 row13" >3</th>
#       <td id="T_476eb_row13_col0" class="data row13 col0" >0.888889</td>
#       <td id="T_476eb_row13_col1" class="data row13 col1" >0.111111</td>
#     </tr>
#     <tr>
#       <th id="T_476eb_level1_row14" class="row_heading level1 row14" >4</th>
#       <td id="T_476eb_row14_col0" class="data row14 col0" >1.000000</td>
#       <td id="T_476eb_row14_col1" class="data row14 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_476eb_level0_row15" class="row_heading level0 row15" rowspan="3">Research Director</th>
#       <th id="T_476eb_level1_row15" class="row_heading level1 row15" >3</th>
#       <td id="T_476eb_row15_col0" class="data row15 col0" >1.000000</td>
#       <td id="T_476eb_row15_col1" class="data row15 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_476eb_level1_row16"

# %%
pd.crosstab(df["Department"], df["Gender"], margins=True, margins_name="Total")
# Out:
# Gender                  Female  Male  Total
# Department
# Human Resources             20    43     63
# Research & Development     379   582    961
# Sales                      189   257    446
# Total                      588   882   1470

# %%
df.pivot_table(index=["Department", "Gender"], columns="Attrition", aggfunc="size")
# Out:
# Attrition                       No  Yes
# Department             Gender
# Human Resources        Female   14    6
#                        Male     37    6
# Research & Development Female  336   43
#                        Male    492   90
# Sales                  Female  151   38
#                        Male    203   54

# %%
pd.crosstab(df["JobRole"], df["Gender"], margins=True, margins_name="Total")
# Out:
# Gender                     Female  Male  Total
# JobRole
# Healthcare Representative      51    80    131
# Human Resources                16    36     52
# Laboratory Technician          85   174    259
# Manager                        47    55    102
# Manufacturing Director         72    73    145
# Research Director              33    47     80
# Research Scientist            114   178    292
# Sales Executive               132   194    326
# Sales Representative           38    45     83
# Total                         588   882   1470

# %%
df.pivot_table(index=["JobRole", "Gender"], columns="Attrition", aggfunc="size")
# Out:
# Attrition                          No  Yes
# JobRole                   Gender
# Healthcare Representative Female   46    5
#                           Male     76    4
# Human Resources           Female   10    6
#                           Male     30    6
# Laboratory Technician     Female   69   16
#                           Male    128   46
# Manager                   Female   45    2
#                           Male     52    3
# Manufacturing Director    Female   68    4
#                           Male     67    6
# Research Director         Female   32    1
#                           Male     46    1
# Research Scientist        Female   97   17
#                           Male    148   30
# Sales Executive           Female  112   20
#                           Male    157   37
# Sales Representative      Female   22   16
#                           Male     28   17

# %%
df.groupby("Education")["MonthlyIncome"].mean()
# Out:
# Education
# 1    5640.570588
# 2    6226.645390
# 3    6517.263986
# 4    6832.402010
# 5    8277.645833
# Name: MonthlyIncome, dtype: float64

# %%
mapeamento_educacao = {
    1: "Below College",
    2: "College",
    3: "Bachelor",
    4: "Master",
    5: "PhD",
}

# %%
df.groupby("Education")["MonthlyIncome"].mean().rename(index=mapeamento_educacao)
# Out:
# Education
# Below College    5640.570588
# College          6226.645390
# Bachelor         6517.263986
# Master           6832.402010
# PhD              8277.645833
# Name: MonthlyIncome, dtype: float64

# %%
df.groupby("Education").size().rename(index=mapeamento_educacao)
# Out:
# Education
# Below College    170
# College          282
# Bachelor         572
# Master           398
# PhD               48
# dtype: int64

# %%
df.groupby(["Education", "Attrition"]).size().rename(index=mapeamento_educacao)
# Out:
# Education      Attrition
# Below College  No           139
#                Yes           31
# College        No           238
#                Yes           44
# Bachelor       No           473
#                Yes           99
# Master         No           340
#                Yes           58
# PhD            No            43
#                Yes            5
# dtype: int64

# %%
pd.crosstab(df["Education"], df["Attrition"], margins=True, margins_name="Total").rename(index=mapeamento_educacao)
# Out:
# Attrition        No  Yes  Total
# Education
# Below College   139   31    170
# College         238   44    282
# Bachelor        473   99    572
# Master          340   58    398
# PhD              43    5     48
# Total          1233  237   1470

# %%
pd.crosstab(
    df["Education"], 
    df["Attrition"], 
    margins=True, 
    margins_name="Total",
    normalize="index",
).rename(index=mapeamento_educacao)
# Out:
# Attrition            No       Yes
# Education
# Below College  0.817647  0.182353
# College        0.843972  0.156028
# Bachelor       0.826923  0.173077
# Master         0.854271  0.145729
# PhD            0.895833  0.104167
# Total          0.838776  0.161224

# %%
pd.crosstab(
    df["Education"], 
    df["Attrition"], 
    margins=True, 
    margins_name="Total",
    normalize="columns",
).rename(index=mapeamento_educacao)
# Out:
# Attrition            No       Yes     Total
# Education
# Below College  0.112733  0.130802  0.115646
# College        0.193025  0.185654  0.191837
# Bachelor       0.383617  0.417722  0.389116
# Master         0.275750  0.244726  0.270748
# PhD            0.034874  0.021097  0.032653

# %%
pd.crosstab(df["Education"], df["Department"], margins=True, margins_name="Total").rename(index=mapeamento_educacao)
# Out:
# Department     Human Resources  Research & Development  Sales  Total
# Education
# Below College                5                     115     50    170
# College                     13                     182     87    282
# Bachelor                    27                     379    166    572
# Master                      15                     255    128    398
# PhD                          3                      30     15     48
# Total                       63                     961    446   1470

# %%
pd.crosstab(df["Education"], df["JobRole"], margins=True, margins_name="Total").rename(index=mapeamento_educacao)
# Out:
# JobRole        Healthcare Representative  Human Resources  \
# Education
# Below College                         15                5
# College                               21               12
# Bachelor                              48               22
# Master                                44               10
# PhD                                    3                3
# Total                                131               52
#
# JobRole        Laboratory Technician  Manager  Manufacturing Director  \
# Education
# Below College                     35        9                      15
# College                           57       19                      33
# Bachelor                         104       40                      54
# Master                            58       29                      38
# PhD                                5        5                       5
# Total                            259      102                     145
#
# JobRole        Research Director  Research Scientist  Sales Executive  \
# Education
# Below College                  7                  37               27
# College                       13                  46               66
# Bachelor                      30                 122              120
# Master                        23                  79              101
# PhD                            7                   8               12
# Total                         80                 292              326
#
# JobRole        Sales Representative  Total
# Education
# Below College                    20    170
# College                          15    282
# Bachelor                         32    572
# Master                           16    398
# PhD                               0     48
# Total                            83   1470

# %%
pd.crosstab(
    df["Education"], 
    df["JobRole"], 
    margins=True, 
    margins_name="Total",
    normalize="index",
).rename(index=mapeamento_educacao)
# Out:
# JobRole        Healthcare Representative  Human Resources  \
# Education
# Below College                   0.088235         0.029412
# College                         0.074468         0.042553
# Bachelor                        0.083916         0.038462
# Master                          0.110553         0.025126
# PhD                             0.062500         0.062500
# Total                           0.089116         0.035374
#
# JobRole        Laboratory Technician   Manager  Manufacturing Director  \
# Education
# Below College               0.205882  0.052941                0.088235
# College                     0.202128  0.067376                0.117021
# Bachelor                    0.181818  0.069930                0.094406
# Master                      0.145729  0.072864                0.095477
# PhD                         0.104167  0.104167                0.104167
# Total                       0.176190  0.069388                0.098639
#
# JobRole        Research Director  Research Scientist  Sales Executive  \
# Education
# Below College           0.041176            0.217647         0.158824
# College                 0.046099            0.163121         0.234043
# Bachelor                0.052448            0.213287         0.209790
# Master                  0.057789            0.198492         0.253769
# PhD                     0.145833            0.166667         0.250000
# Total                   0.054422            0.198639         0.221769
#
# JobRole        Sales Representative
# Education
# Below College              0.117647
# College                    0.053191
# Bachelor                   0.055944
# Master                     0.040201
# PhD                        0.000000
# Total                      0.056463

# %%
pd.crosstab(
    df["Education"], 
    df["JobRole"], 
    margins=True, 
    margins_name="Total",
    normalize="columns",
).rename(index=mapeamento_educacao)
# Out:
# JobRole        Healthcare Representative  Human Resources  \
# Education
# Below College                   0.114504         0.096154
# College                         0.160305         0.230769
# Bachelor                        0.366412         0.423077
# Master                          0.335878         0.192308
# PhD                             0.022901         0.057692
#
# JobRole        Laboratory Technician   Manager  Manufacturing Director  \
# Education
# Below College               0.135135  0.088235                0.103448
# College                     0.220077  0.186275                0.227586
# Bachelor                    0.401544  0.392157                0.372414
# Master                      0.223938  0.284314                0.262069
# PhD                         0.019305  0.049020                0.034483
#
# JobRole        Research Director  Research Scientist  Sales Executive  \
# Education
# Below College             0.0875            0.126712         0.082822
# College                   0.1625            0.157534         0.202454
# Bachelor                  0.3750            0.417808         0.368098
# Master                    0.2875            0.270548         0.309816
# PhD                       0.0875            0.027397         0.036810
#
# JobRole        Sales Representative     Total
# Education
# Below College              0.240964  0.115646
# College                    0.180723  0.191837
# Bachelor                   0.385542  0.389116
# Master                     0.192771  0.270748
# PhD                        0.000000  0.032653

# %%
pd.crosstab(
    df["Education"], 
    df["JobRole"], 
    margins=True, 
    margins_name="Total",
    normalize="columns",
).rename(index=mapeamento_educacao).mul(100).round(2)
# Out:
# JobRole        Healthcare Representative  Human Resources  \
# Education
# Below College                      11.45             9.62
# College                            16.03            23.08
# Bachelor                           36.64            42.31
# Master                             33.59            19.23
# PhD                                 2.29             5.77
#
# JobRole        Laboratory Technician  Manager  Manufacturing Director  \
# Education
# Below College                  13.51     8.82                   10.34
# College                        22.01    18.63                   22.76
# Bachelor                       40.15    39.22                   37.24
# Master                         22.39    28.43                   26.21
# PhD                             1.93     4.90                    3.45
#
# JobRole        Research Director  Research Scientist  Sales Executive  \
# Education
# Below College               8.75               12.67             8.28
# College                    16.25               15.75            20.25
# Bachelor                   37.50               41.78            36.81
# Master                     28.75               27.05            30.98
# PhD                         8.75                2.74             3.68
#
# JobRole        Sales Representative  Total
# Education
# Below College                 24.10  11.56
# College                       18.07  19.18
# Bachelor                      38.55  38.91
# Master                        19.28  27.07
# PhD                            0.00   3.27

# %%
pd.crosstab(
    df["Education"], 
    df["JobLevel"], 
    margins=True, 
    margins_name="Total",
    normalize="index",
).rename(index=mapeamento_educacao).mul(100).round(2)
# Out:
# JobLevel           1      2      3      4     5
# Education
# Below College  52.35  27.65  11.76   4.71  3.53
# College        33.33  44.33  11.70   6.03  4.61
# Bachelor       40.38  29.90  17.13   7.69  4.90
# Master         30.40  42.96  14.57   7.04  5.03
# PhD            16.67  41.67  18.75  18.75  4.17
# Total          36.94  36.33  14.83   7.21  4.69

# %%
pd.crosstab(
    df["Education"], 
    df["JobLevel"], 
    margins=True, 
    margins_name="Total",
    normalize="columns",
).rename(index=mapeamento_educacao).mul(100).round(2)
# Out:
# JobLevel           1      2      3      4      5  Total
# Education
# Below College  16.39   8.80   9.17   7.55   8.70  11.56
# College        17.31  23.41  15.14  16.04  18.84  19.18
# Bachelor       42.54  32.02  44.95  41.51  40.58  38.91
# Master         22.28  32.02  26.61  26.42  28.99  27.07
# PhD             1.47   3.75   4.13   8.49   2.90   3.27

# %%
pd.crosstab(
    [df["JobRole"], df["Education"]],
    df["JobLevel"], 
    margins=True, 
    margins_name="Total",
).rename(index=mapeamento_educacao)
# Out:
# JobLevel                                   1    2    3    4   5  Total
# JobRole                   Education
# Healthcare Representative Below College    0    8    5    2   0     15
#                           College          0   15    4    2   0     21
#                           Bachelor         0   25   20    3   0     48
#                           Master           0   28   15    1   0     44
#                           PhD              0    2    0    1   0      3
# Human Resources           Below College    4    1    0    0   0      5
#                           College          9    2    1    0   0     12
#                           Bachelor        13    6    3    0   0     22
#                           Master           6    2    2    0   0     10
#                           PhD              1    2    0    0   0      3
# Laboratory Technician     Below College   32    3    0    0   0     35
#                           College         39   16    2    0   0     57
#                           Bachelor        82   21    1    0   0    104
#                           Master          45   13    0    0   0     58
#                           PhD              2    3    0    0   0      5
# Manager                   Below College    0    0    2    4   3      9
#                           College          0    0    1    9   9     19
#                           Bachelor         0    0    6   17  17     40
#                           Master           0    0    3   13  13     29
#                           PhD              0    0    0    4   1      5
# Manufacturing Director    Below College    0   10    4    1   0     15
#                           College          0   24    7    2   0     33
#                           Bachelor         0   26   24    4   0     54
#                           Master           0   28    7    3   0     38
#                           PhD              0    2    3    0   0      5
# Research Director         Below College    0    0    4    0   3      7
#                           College          0    0    5    4   4     13
#                           Bachelor         0    0    8   11  11     30
#                           Master           0    0    9    7   7     23
#                           PhD              0    0    2    4   1      7
# Research Scientist        Below College   35    2    0    0   0     37
#                           College         33   13    0    0   0     46
#                           Bachelor       105   16    1    0   0    122
#                           Master          56   23    0    0   0     79
#                           PhD              5    3    0    0   0      8
# Sales Executive           Below College    0   21    5    1   0     27
#                           College          0   53   13    0   0     66
#                           Bachelor         0   76   35    9   0    120
#                           Master           0   75   22    4   0    101
#                           PhD              0    8    4    0   0     12
# Sales Representative      Below College   18    2    0    0   0     20
#                           College         13    2    0    0   0     15
#                           Bachelor        31    1    0    0   0     32
#                           Master          14    2    0    0   0     16
# Total                                    543  534  218  106  69   1470

# %%
pd.crosstab(
    [df["JobRole"], df["JobLevel"], df["Attrition"]],
    df["Education"], 
    margins=True, 
    margins_name="Total",
).rename(columns=mapeamento_educacao)
# Out:
# Education                                     Below College  College  \
# JobRole                   JobLevel Attrition
# Healthcare Representative 2        No                     7       13
#                                    Yes                    1        2
#                           3        No                     4        3
#                                    Yes                    1        1
#                           4        No                     2        2
#                                    Yes                    0        0
# Human Resources           1        No                     3        7
#                                    Yes                    1        2
#                           2        No                     1        2
#                           3        No                     0        0
#                                    Yes                    0        1
# Laboratory Technician     1        No                    24       30
#                                    Yes                    8        9
#                           2        No                     3       14
#                                    Yes                    0        2
#                           3        No                     0        1
#                                    Yes                    0        1
# Manager                   3        No                     1        1
#                                    Yes                    1        0
#                           4        No                     4        9
#                           5        No                     2        9
#                                    Yes                    1        0
# Manufacturing Director    2        No                     9       23
#                                    Yes                    1        1
#                           3        No                     4        7
#                                    Yes                    0        0
#                           4        No                     1        2
# Research Director         3        No                     4        5
#                           4        No                     0        4
#                           5        No                     3        4
#                                    Yes                    0        0
# Research Scientist        1        No                    28       26
#                                    Yes                    7        7
#                           2        No                     2       13
#                                    Yes                    0        0
#                           3        No                     0        0
# Sales Executive           2        No                    20       43
#                                    Yes                    1       10
#                           3        No                     3       12
#                                    Yes                    2        1
#                           4        No                     1        0
#                                    Yes                    0        0
# Sales Representative      1        No                    11        6
#                                    Yes                    7        7
#                           2        No                     2        2
#                                    Yes                    0        0
# Total                                                   170      282
#
# Education                                     Bachelor  Master  PhD  Total
# JobRole                   JobLevel Attrition
# Healthcare Representative 2        No               25      28    2     75
#                                    Yes               0       0    0      3
#                           3        No               18      14    0     39
#                                    Yes               2       1    0      5
#                           4        No                2       1    1      8
#                                    Yes               1       0    0      1
# Human Resources           1        No               10       3    0     23
#                                    Yes               3       3    1     10
#                           2        No                6       2    2     13
#                           3        No                2       2    0      4
#                                    Yes               1       0    0      2
# Laboratory Technician     1        No               53      35    2    144
#                                    Yes              29      10    0     56
#                           2        No               19      12    3     51
#                                    Yes               2       1    0      5
#                           3        No                1       0    0      2
#                                    Yes               0       0    0      1
# Manager                   3        No                6       2    0     10
#                                    Yes               0       1    0      2
#                           4        No               17      13    4     47
#                           5        No               15      13    1     40
#                                    Yes               2       0    0      3
# Manufacturing Director    2        No               25      26    2     85
#                                    Yes               1       2    0      5
#                           3        No               23       5    1     40
#                                    Yes               1       2    2      5
#                           4        No                4       3    0     10
# Research Director         3        No                8       9    2     28
#                           4        No               11       7    4     26
#                           5        No               10       6    1     24
#                                    Yes               1       1    0      2
# Research Scientist        1        No               87      44    4    189
#                                    Yes              18      12    1     45
#                           2        No               16      21    3     55
#                                    Yes               0       2    0      2
#                           3        No                1       0    0      1
# Sales Executive           2        No               66      61    7    197
#                                    Yes              10      14    1     36
#                           3        No               26      17    4     62
#                                    Yes               9       5    0     17
#                           4        No                6       3    0     10
#                                    Yes               3       1    0      4
# Sales Representative      1        No               16      11    0     44
#                                    Yes              15       3    0     32
#                           2        No                0       2    0      6
#                                    Yes               1       0    0      1
# Total                                              572     398   48   1470

# %% [markdown]
# ## Noções de estatística

# %% [markdown]
# ### Histogramas
#
# Um histograma é uma representação visual da distribuição de dados quantitativos. Para construir um histograma, o primeiro passo é agrupar o intervalo de valores - dividir todo o intervalo de valores em uma série de intervalos - e depois contar quantos valores caem em cada intervalo. Os intervalos (*bins*, em inglês) são geralmente especificados como intervalos consecutivos e não sobrepostos de uma variável. Os bins devem ser adjacentes e geralmente (mas não são obrigados a ser) de tamanho igual.
#
# Os histogramas dão uma ideia aproximada da densidade da distribuição subjacente dos dados e muitas vezes para a estimativa de densidade, ou seja estimar a probabilidade da variável subjacente.
#
# #### Histogramas vs gráfico de barras
#
# Os histogramas são às vezes confundidos com gráficos de barras. Um histograma é usado para dados quantitativos, onde os bins representam intervalos de valores, enquanto um gráfico de barras é um gráfico de variáveis categóricas.
#
# Um gráfico de barras é um gráfico que usa barras para representar a frequência ou quantidade de diferentes categorias de dados.
#
# Um histograma, por outro lado, é um gráfico que mostra a distribuição de dados numéricos. É um tipo de gráfico de barras que mostra a frequência ou número de observações dentro de diferentes intervalos numéricos, chamados de bins. Os bins são geralmente especificados como intervalos consecutivos e não sobrepostos de uma variável. O histograma fornece uma representação visual da distribuição dos dados, mostrando o número de observações que caem em cada bin. Isso pode ser útil para identificar padrões e tendências nos dados e para fazer comparações entre diferentes conjuntos de dados.

# %%
df.groupby("Gender").size()
# Out:
# Gender
# Female    588
# Male      882
# dtype: int64

# %%
df.groupby("Gender")["Age"].value_counts(bins=10)
# Out:
# Gender  Age
# Female  (34.8, 39.0]                  117
#         (30.6, 34.8]                  108
#         (26.4, 30.6]                   89
#         (39.0, 43.2]                   69
#         (43.2, 47.4]                   56
#         (51.6, 55.8]                   36
#         (47.4, 51.6]                   35
#         (22.2, 26.4]                   32
#         (17.956999999999997, 22.2]     25
#         (55.8, 60.0]                   21
# Male    (34.8, 39.0]                  180
#         (30.6, 34.8]                  157
#         (26.4, 30.6]                  135
#         (39.0, 43.2]                  106
#         (43.2, 47.4]                   75
#         (22.2, 26.4]                   73
#         (47.4, 51.6]                   57
#         (51.6, 55.8]                   41
#         (17.956999999999997, 22.2]     32
#         (55.8, 60.0]                   26
# Name: Age, dtype: int64

# %%
df.groupby("Gender")["Age"].value_counts(bins=10).sort_index()
# Out:
# Gender  Age
# Female  (17.956999999999997, 22.2]     25
#         (22.2, 26.4]                   32
#         (26.4, 30.6]                   89
#         (30.6, 34.8]                  108
#         (34.8, 39.0]                  117
#         (39.0, 43.2]                   69
#         (43.2, 47.4]                   56
#         (47.4, 51.6]                   35
#         (51.6, 55.8]                   36
#         (55.8, 60.0]                   21
# Male    (17.956999999999997, 22.2]     32
#         (22.2, 26.4]                   73
#         (26.4, 30.6]                  135
#         (30.6, 34.8]                  157
#         (34.8, 39.0]                  180
#         (39.0, 43.2]                  106
#         (43.2, 47.4]                   75
#         (47.4, 51.6]                   57
#         (51.6, 55.8]                   41
#         (55.8, 60.0]                   26
# Name: Age, dtype: int64

# %%
df.groupby("Gender")["Age"].value_counts(bins=10, normalize=True).mul(100).round(1).sort_index()
# Out:
# Gender  Age
# Female  (17.956999999999997, 22.2]     4.3
#         (22.2, 26.4]                   5.4
#         (26.4, 30.6]                  15.1
#         (30.6, 34.8]                  18.4
#         (34.8, 39.0]                  19.9
#         (39.0, 43.2]                  11.7
#         (43.2, 47.4]                   9.5
#         (47.4, 51.6]                   6.0
#         (51.6, 55.8]                   6.1
#         (55.8, 60.0]                   3.6
# Male    (17.956999999999997, 22.2]     3.6
#         (22.2, 26.4]                   8.3
#         (26.4, 30.6]                  15.3
#         (30.6, 34.8]                  17.8
#         (34.8, 39.0]                  20.4
#         (39.0, 43.2]                  12.0
#         (43.2, 47.4]                   8.5
#         (47.4, 51.6]                   6.5
#         (51.6, 55.8]                   4.6
#         (55.8, 60.0]                   2.9
# Name: Age, dtype: float64

# %%
df.groupby("Gender")["Age"].plot(kind="hist", legend=True, alpha=0.5)
# Out:
# Gender
# Female    Axes(0.125,0.11;0.775x0.77)
# Male      Axes(0.125,0.11;0.775x0.77)
# Name: Age, dtype: object

# %%
df.hist(column="Age", by="Gender")
# Out:
# array([<Axes: title={'center': 'Female'}>,
#        <Axes: title={'center': 'Male'}>], dtype=object)

# %%
df.hist(column="Age", by="Gender", sharey=True)
# Out:
# array([<Axes: title={'center': 'Female'}>,
#        <Axes: title={'center': 'Male'}>], dtype=object)

# %%
df.hist(column="Age", by="Gender", layout=(2, 1), sharex=True, figsize=(5, 7))
# Out:
# array([<Axes: title={'center': 'Female'}>,
#        <Axes: title={'center': 'Male'}>], dtype=object)

# %%
df.groupby("Attrition").size()
# Out:
# Attrition
# No     1233
# Yes     237
# dtype: int64

# %%
df.groupby("Attrition")["Age"].mean()
# Out:
# Attrition
# No     37.561233
# Yes    33.607595
# Name: Age, dtype: float64

# %%
df.groupby("Attrition")["Age"].value_counts(bins=10).sort_index()
# Out:
# Attrition  Age
# No         (17.956999999999997, 22.2]     30
#            (22.2, 26.4]                   76
#            (26.4, 30.6]                  180
#            (30.6, 34.8]                  215
#            (34.8, 39.0]                  267
#            (39.0, 43.2]                  160
#            (43.2, 47.4]                  116
#            (47.4, 51.6]                   81
#            (51.6, 55.8]                   69
#            (55.8, 60.0]                   39
# Yes        (17.959, 22.0]                 27
#            (22.0, 26.0]                   29
#            (26.0, 30.0]                   44
#            (30.0, 34.0]                   50
#            (34.0, 38.0]                   24
#            (38.0, 42.0]                   19
#            (42.0, 46.0]                   14
#            (46.0, 50.0]                   12
#            (50.0, 54.0]                    7
#            (54.0, 58.0]                   11
# Name: Age, dtype: int64

# %%
df.groupby("Attrition")["Age"].value_counts(bins=10, normalize=True).mul(100).round(1).sort_index()
# Out:
# Attrition  Age
# No         (17.956999999999997, 22.2]     2.4
#            (22.2, 26.4]                   6.2
#            (26.4, 30.6]                  14.6
#            (30.6, 34.8]                  17.4
#            (34.8, 39.0]                  21.7
#            (39.0, 43.2]                  13.0
#            (43.2, 47.4]                   9.4
#            (47.4, 51.6]                   6.6
#            (51.6, 55.8]                   5.6
#            (55.8, 60.0]                   3.2
# Yes        (17.959, 22.0]                11.4
#            (22.0, 26.0]                  12.2
#            (26.0, 30.0]                  18.6
#            (30.0, 34.0]                  21.1
#            (34.0, 38.0]                  10.1
#            (38.0, 42.0]                   8.0
#            (42.0, 46.0]                   5.9
#            (46.0, 50.0]                   5.1
#            (50.0, 54.0]                   3.0
#            (54.0, 58.0]                   4.6
# Name: Age, dtype: float64

# %%
df.hist(column="Age", by="Attrition", bins=10)
# Out:
# array([<Axes: title={'center': 'No'}>, <Axes: title={'center': 'Yes'}>],
#       dtype=object)

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.cut.html

# %%
colunas_categoricas_nao_ordenadas
# Out:
# ['BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'JobRole',
#  'MaritalStatus',
#  'OverTime']

# %%
colunas_categoricas_ordenadas
# Out:
# ['Education',
#  'EnvironmentSatisfaction',
#  'JobSatisfaction',
#  'JobInvolvement',
#  'JobLevel',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StockOptionLevel',
#  'WorkLifeBalance']

# %%
colunas_numericas
# Out:
# ['Age',
#  'DailyRate',
#  'DistanceFromHome',
#  'HourlyRate',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'PercentSalaryHike',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
faixas_idade = [0, 20, 30, 50, float("inf")]  # (0-20], (20-30], (30-50], (50+]
rotulos = ["Adolescente", "Jovem adulto", "Adulto médio", "Adulto sênior"]

df["FaixaEtaria"] = pd.cut(df["Age"], bins=faixas_idade, labels=rotulos)

df[["Age", "FaixaEtaria"]].head(20)
# Out:
#     Age    FaixaEtaria
# 0    41   Adulto médio
# 1    49   Adulto médio
# 2    37   Adulto médio
# 3    33   Adulto médio
# 4    27   Jovem adulto
# 5    32   Adulto médio
# 6    59  Adulto sênior
# 7    30   Jovem adulto
# 8    38   Adulto médio
# 9    36   Adulto médio
# 10   35   Adulto médio
# 11   29   Jovem adulto
# 12   31   Adulto médio
# 13   34   Adulto médio
# 14   28   Jovem adulto
# 15   29   Jovem adulto
# 16   32   Adulto médio
# 17   22   Jovem adulto
# 18   53  Adulto sênior
# 19   38   Adulto médio

# %%
df[["Age", "FaixaEtaria"]].tail(20)
# Out:
#       Age   FaixaEtaria
# 1450   35  Adulto médio
# 1451   38  Adulto médio
# 1452   50  Adulto médio
# 1453   36  Adulto médio
# 1454   45  Adulto médio
# 1455   40  Adulto médio
# 1456   35  Adulto médio
# 1457   40  Adulto médio
# 1458   35  Adulto médio
# 1459   29  Jovem adulto
# 1460   29  Jovem adulto
# 1461   50  Adulto médio
# 1462   39  Adulto médio
# 1463   31  Adulto médio
# 1464   26  Jovem adulto
# 1465   36  Adulto médio
# 1466   39  Adulto médio
# 1467   27  Jovem adulto
# 1468   49  Adulto médio
# 1469   34  Adulto médio

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 32 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   category
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   category
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   category
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   category
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
#  13  JobRole                   1470 non-null   category
#  14  JobSatisfaction           1470 non-null   int64
#  15  MaritalStatus             1470 non-null   category
#  16  MonthlyIncome             1470 non-null   int64
#  17  MonthlyRate               1470 non-null   int64
#  18  NumCompaniesWorked        1470 non-null   int64
#  19  OverTime                  1470 non-null   category
#  20  PercentSalaryHike         1470 non-null   int64
#  21  PerformanceRating         1470 non-null   int64
#  22  RelationshipSatisfaction  1470 non-null   int64
#  23  StockOptionLevel          1470 non-null   int64
#  24  TotalWorkingYears         1470 non-null   int64
#  25  TrainingTimesLastYear     1470 non-null   int64
#  26  WorkLifeBalance           1470 non-null   int64
#  27  YearsAtCompany            1470 non-null   int64
#  28  YearsInCurrentRole        1470 non-null   int64
#  29  YearsSinceLastPromotion   1470 non-null   int64
#  30  YearsWithCurrManager      1470 non-null   int64
#  31  FaixaEtaria               1470 non-null   category
# dtypes: category(8), int64(23), object(1)
# memory usage: 288.6+ KB

# %%
for coluna in df.select_dtypes(include="category"):
    print(f"{coluna}")
    print(f"{coluna}.cat.categories: {df[coluna].cat.categories}")
    print(f"{coluna}.cat.ordered: {df[coluna].cat.ordered}")
    print(f"{coluna}.cat.codes: {df[coluna].cat.codes.unique()}")
    print()
# Out:
# BusinessTravel
# BusinessTravel.cat.categories: Index(['Non-Travel', 'Travel_Frequently', 'Travel_Rarely'], dtype='object')
# BusinessTravel.cat.ordered: False
# BusinessTravel.cat.codes: [2 1 0]
#
# Department
# Department.cat.categories: Index(['Human Resources', 'Research & Development', 'Sales'], dtype='object')
# Department.cat.ordered: False
# Department.cat.codes: [2 1 0]
#
# EducationField
# EducationField.cat.categories: Index(['Human Resources', 'Life Sciences', 'Marketing', 'Medical', 'Other',
#        'Technical Degree'],
#       dtype='object')
# EducationField.cat.ordered: False
# EducationField.cat.codes: [1 4 3 2 5 0]
#
# Gender
# Gender.cat.categories: Index(['Female', 'Male'], dtype='object')
# Gender.cat.ordered: False
# Gender.cat.codes: [0 1]
#
# JobRole
# JobRole.cat.categories: Index(['Healthcare Representative', 'Human Resources', 'Laboratory Technician',
#        'Manager', 'Manufacturing Director', 'Research Director',
#        'Research Scientist', 'Sales Executive', 'Sales Representative'],
#       dtype='object')
# JobRole.cat.ordered: False
# JobRole.cat.codes: [7 6 2 4 0 3 8 5 1]
#
# MaritalStatus
# MaritalStatus.cat.categories: Index(['Divorced', 'Married', 'Single'], dtype='object')
# MaritalStatus.cat.ordered: False
# MaritalStatus.cat.codes: [2 1 0]
#
# OverTime
# OverTime.cat.categories: Index(['No', 'Yes'], dtype='object')
# OverTime.cat.ordered: False
# OverTime.cat.codes: [1 0]
#
# FaixaEtaria
# FaixaEtaria.cat.categories: Index(['Adolescente', 'Jovem adulto', 'Adulto médio', 'Adulto sênior'], dtype='object')
# FaixaEtaria.cat.ordered: True
# FaixaEtaria.cat.codes: [2 1 3 0]

# %%
df["FaixaEtaria"].value_counts()
# Out:
# Adulto médio     941
# Jovem adulto     358
# Adulto sênior    143
# Adolescente       28
# Name: FaixaEtaria, dtype: int64

# %%
df["FaixaEtaria"].value_counts().sort_index()
# Out:
# Adolescente       28
# Jovem adulto     358
# Adulto médio     941
# Adulto sênior    143
# Name: FaixaEtaria, dtype: int64

# %%
df["FaixaEtaria"].value_counts().sort_index().plot(kind="bar")
# Out:
# <Axes: >

# %%
pd.crosstab(df["FaixaEtaria"], df["Attrition"], normalize="index").mul(100).round(1).style.background_gradient(cmap="RdYlGn", axis="columns")
# Out:
# <style type="text/css">
# #T_2f1b0_row0_col0, #T_2f1b0_row1_col1, #T_2f1b0_row2_col1, #T_2f1b0_row3_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_2f1b0_row0_col1, #T_2f1b0_row1_col0, #T_2f1b0_row2_col0, #T_2f1b0_row3_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2f1b0">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_2f1b0_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_2f1b0_level0_col1" class="col_heading level0 col1" >Yes</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >FaixaEtaria</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f1b0_level0_row0" class="row_heading level0 row0" >Adolescente</th>
#       <td id="T_2f1b0_row0_col0" class="data row0 col0" >42.900000</td>
#       <td id="T_2f1b0_row0_col1" class="data row0 col1" >57.100000</td>
#     </tr>
#     <tr>
#       <th id="T_2f1b0_level0_row1" class="row_heading level0 row1" >Jovem adulto</th>
#       <td id="T_2f1b0_row1_col0" class="data row1 col0" >76.500000</td>
#       <td id="T_2f1b0_row1_col1" class="data row1 col1" >23.500000</td>
#     </tr>
#     <tr>
#       <th id="T_2f1b0_level0_row2" class="row_heading level0 row2" >Adulto médio</th>
#       <td id="T_2f1b0_row2_col0" class="data row2 col0" >87.400000</td>
#       <td id="T_2f1b0_row2_col1" class="data row2 col1" >12.600000</td>
#     </tr>
#     <tr>
#       <th id="T_2f1b0_level0_row3" class="row_heading level0 row3" >Adulto sênior</th>
#       <td id="T_2f1b0_row3_col0" class="data row3 col0" >87.400000</td>
#       <td id="T_2f1b0_row3_col1" class="data row3 col1" >12.600000</td>
#     </tr>
#   </tbody>
# </table>

# %%
colunas_categoricas_ordenadas.append("FaixaEtaria")

# %%
colunas_categoricas_ordenadas
# Out:
# ['Education',
#  'EnvironmentSatisfaction',
#  'JobSatisfaction',
#  'JobInvolvement',
#  'JobLevel',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StockOptionLevel',
#  'WorkLifeBalance',
#  'FaixaEtaria']

# %%
df[colunas_numericas].hist(figsize=(15, 10));

# %% [markdown]
# ### Boxplots

# %% [markdown]
# Um boxplot é um método para demonstrar graficamente a localidade (tendência central), dispersão e assimetria de grupos de dados numéricos através de seus quartis.
#
# Além da caixa em um boxplot, pode haver linhas (chamadas de *whiskers*, bigodes em portuês) que se estendem da caixa indicando variabilidade (distância entre os valores) fora dos quartis superiores e inferiores. Outliers que diferem significativamente do restante do conjunto de dados podem ser plotados como pontos individuais além dos bigodes no boxplot. Boxplots são não-paramétricos: eles exibem variação em amostras de uma população estatística sem fazer nenhuma suposição sobre a distribuição estatística subjacente. Os espaçamentos em cada subseção do boxplot indicam o grau de dispersão e assimetria dos dados. Boxplots podem ser desenhados horizontalmente ou verticalmente.
#
# Um boxplot é uma maneira padronizada de exibir o conjunto de dados com base no resumo dos cinco números: o mínimo, o máximo, a mediana da amostra e o primeiro e terceiro quartis.
#
# - Mínimo (Q0 ou 0º percentil): o ponto de dados mais baixo no conjunto de dados, excluindo quaisquer outliers
# - Máximo (Q4 ou 100º percentil): o ponto de dados mais alto no conjunto de dados, excluindo quaisquer outliers
# - Mediana (Q2 ou 50º percentil): o valor do meio no conjunto de dados
# - Primeiro quartil (Q1 ou 25º percentil): também conhecido como quartil inferior, é a mediana da metade inferior do conjunto de dados.
# - Terceiro quartil (Q3 ou 75º percentil): também conhecido como quartil superior, é a mediana da metade superior do conjunto de dados.
#
# Além dos valores mínimo e máximo usados para construir um boxplot, outro elemento importante que também pode ser empregado para obter um boxplot é a amplitude interquartil (IQR), a distância entre os quartis superior e inferior.

# %% [markdown]
# ![download.webp](attachment:48a3d722-313d-495f-83a1-bfaeb6dea9da.webp)

# %% [markdown]
# ![download.webp](attachment:9383ffc5-539a-4fa8-b440-5b8f62cbe6c2.webp)

# %% [markdown]
# #### Comparando boxplots

# %% [markdown]
# - Compare as medianas. Se a linha da mediana de um boxplot está fora da caixa de outro boxplot, então os dois grupos comparados são provavelmente diferentes.
# - Compare os IQRs e os whiskers para ter uma ideia das diferentes dispersões.
# - Compare o comportamento dos outliers.
# - Compare *skewness* (assimetria)

# %% [markdown]
# ![download.webp](attachment:200c94af-5f21-42b2-92be-eca0c9b3b98c.webp)

# %%
df["DistanceFromHome"].hist()
# Out:
# <Axes: >

# %%
df.boxplot(column="DistanceFromHome", vert=False, grid=False, showmeans=True)
# Out:
# <Axes: >

# %%
df["DistanceFromHome"].describe()
# Out:
# count    1470.000000
# mean        9.192517
# std         8.106864
# min         1.000000
# 25%         2.000000
# 50%         7.000000
# 75%        14.000000
# max        29.000000
# Name: DistanceFromHome, dtype: float64

# %%
df.groupby(["Gender", "Attrition"])["Age"].describe()
# Out:
#                   count       mean       std   min   25%   50%    75%   max
# Gender Attrition
# Female No         501.0  38.155689  9.001762  18.0  31.0  37.0  45.00  60.0
#        Yes         87.0  32.574713  9.385333  18.0  27.0  31.0  36.50  58.0
# Male   No         732.0  37.154372  8.792917  18.0  31.0  36.0  43.00  60.0
#        Yes        150.0  34.206667  9.842584  18.0  28.0  32.0  39.75  58.0

# %%
df.boxplot(column="Age", by=["Gender", "Attrition"], grid=False, showmeans=True)
# Out:
# <Axes: title={'center': 'Age'}, xlabel='[Gender, Attrition]'>

# %%
df.groupby("JobLevel")["Age"].describe()
# Out:
#           count       mean       std   min   25%   50%   75%   max
# JobLevel
# 1         543.0  32.524862  8.463882  18.0  27.0  31.0  37.0  59.0
# 2         534.0  36.599251  7.503875  22.0  31.0  35.5  41.0  60.0
# 3         218.0  40.087156  8.114771  27.0  34.0  38.0  46.0  60.0
# 4         106.0  47.537736  6.485404  29.0  43.0  48.0  53.0  59.0
# 5          69.0  47.753623  5.778779  39.0  42.0  48.0  52.0  60.0

# %%
df.groupby(["Gender", "Attrition"])["JobSatisfaction"].describe()
# Out:
#                   count      mean       std  min  25%  50%  75%  max
# Gender Attrition
# Female No         501.0  2.728543  1.098255  1.0  2.0  3.0  4.0  4.0
#        Yes         87.0  2.425287  1.052485  1.0  2.0  2.0  3.0  4.0
# Male   No         732.0  2.812842  1.089283  1.0  2.0  3.0  4.0  4.0
#        Yes        150.0  2.493333  1.157100  1.0  1.0  3.0  3.0  4.0

# %%
df.boxplot(column="JobSatisfaction", by=["Gender", "Attrition"], grid=False, showmeans=True)
# Out:
# <Axes: title={'center': 'JobSatisfaction'}, xlabel='[Gender, Attrition]'>

# %%
df.boxplot(column="Age", by="JobLevel", grid=False, showmeans=True)
# Out:
# <Axes: title={'center': 'Age'}, xlabel='JobLevel'>

# %%
df.groupby(["JobRole", "Gender", "JobLevel"])["MonthlyIncome"].describe()
# Out:
#                                            count          mean          std  \
# JobRole                   Gender JobLevel
# Healthcare Representative Female 2          31.0   5882.838710  1601.010475
#                                  3          17.0   9123.058824  1305.181188
#                                  4           3.0  13888.000000   133.371661
#                           Male   2          47.0   5853.808511  1026.214204
#                                  3          27.0   9515.629630  1312.786735
#                                  4           6.0  12515.500000  1165.564885
# Human Resources           Female 1          10.0   2653.000000   473.966244
#                                  2           3.0   5859.333333   602.412096
#                                  3           3.0   9514.333333   594.553894
#                           Male   1          23.0   2768.086957   796.490365
#                                  2          10.0   5474.700000  1015.903982
#                                  3           3.0   9731.666667  1514.939713
# Laboratory Technician     Female 1          67.0   2821.208955   665.705607
#                                  2          17.0   4680.176471  1135.106341
#                                  3           1.0   7403.000000          NaN
#                           Male   1         133.0   2871.406015   814.399063
#                                  2          39.0   4357.743590  1301.237058
#                                  3           2.0   5295.500000   120.915260
# Manager                   Female 3           7.0  12376.000000   730.209787
#                                  4          23.0  16657.086957   790.448027
#                                  5          17.0  19133.705882   582.842363
#                           Male   3           5.0  12032.800000   920.125372
#                                  4          24.0  16571.291667  1103.257803
#                                  5          26.0  19216.846154   513.599587
# Manufacturing Director    Female 2          41.0   5259.731707   821.601181
#                                  3          23.0   9189.391304  1351.339058
#                                  4           8.0  13306.875000   375.310324
#                           Male   2          49.0   5908.142857  1551.159969
#                                  3          22.0   9430.045455  1198.465506
#                                  4           2.0  13687.500000   403.757972
# Research Director         Female 3          16.0  12652.000000   988.025708
#                                  4          10.0  16349.100000   853.426225
#                                  5           7.0  19120.714286   645.621332
#                           Male   3          12.0  12814.333333   824.694140
#                                  4          16.0  16479.000000  1271.443956
#                                  5          19.0  19235.789474   420.039625
# Research Scientist        Female 1          87.0   2869.873563   800.612611
#                                  2          27.0   4873.740741  1200.243039
#                           Male   1         147.0   2802.659864   730.420638
#                                  2          30.0   4769.566667   889.066177
#                                  3           1.0   9724.000000          NaN
# Sales Executive           Female 2          98.0   5669.142857  1254.471861
#                                  3          27.0   9075.407407  1184.644161
#                                  4           7.0  13182.428571   549.261582
#                           Male   2         135.0   5896.518519  1533.774112
#                                  3          52.0   9150.730769  1253.430948
#                                  4           7.0  13222.571429   702.481283
# Sales Representative      Female 1          35.0   2516.771429   539.688804
#                                  2           3.0   4482.333333   932.655528
#                           Male   1          41.0   2498.146341   711.439898
#                                  2           4.0   3500.000000  2122.029846
#
#                                                min       25%      50%  \
# JobRole                   Gender JobLevel
# Healthcare Representative Female 2          4014.0   4522.50   5731.0
#                                  3          7094.0   7978.00   8823.0
#                                  4         13734.0  13849.00  13964.0
#                           Male   2          4000.0   5265.50   5745.0
#                                  3          7005.0   8566.50   9884.0
#                                  4         11103.0  11476.00  12832.5
# Human Resources           Female 1          2109.0   2181.75   2741.5
#                                  2          5204.0   5594.50   5985.0
#                                  3          8837.0   9296.50   9756.0
#                           Male   1          1555.0   2222.00   2592.0
#                                  2          3886.0   4622.75   5910.0
#                                  3          7988.0   9235.00  10482.0
# Laboratory Technician     Female 1          1129.0   2388.50   2743.0
#                                  2          2406.0   4011.00   4627.0
#                                  3          7403.0   7403.00   7403.0
#                           Male   1          1102.0   2293.00   2660.0
#                                  2          2042.0   3449.00   4404.0
#                                  3          5210.0   5252.75   5295.5
# Manager                   Female 3         11631.0  11897.00  11996.0
#                                  4         14756.0  16185.50  16752.0
#                                  5         18041.0  18824.00  19094.0
#                           Male   3         11244.0  11557.00  11849.0
#                                  4         14026.0  16222.00  16870.5
#                                  5         18200.0  19050.75  19217.0
# Manufacturing Director    Female 2          4011.0   4663.00   5121.0
#                                  3          7143.0   7808.50   9667.0
#                                  4         12742.0  13097.75  13242.0
#                           Male   2          4033.0   4775.00   5762.0
#                                  3          7260.0   8500.00   9480.0
#                                  4         13402.0  13544.75  13687.5
# Research Director         Female 3         11031.0  11896.00  13198.5
#                                  4         14275.0  16139.00  16417.5
#                                  5         18172.0  18702.50  19049.0
#                           Male   3         11510.0  12122.50  13026.5
#                                  4         14336.0  15543.75  16817.0
#                                  5         18265.0  19112.50  19328.0
# Research Scientist        Female 1          1261.0   2295.00   2632.0
#                                  2          2133.0   4435.50   4869.0
#                           Male   1          1009.0   2341.00   2703.0
#                                  2          3055.0   4257.75   4817.5
#                                  3          9724.0   9724.00   9724.0
# Sales Executive           Female 2          4028.0   4669.25   5461.0
#                                  3          7314.0   7786.00   9071.0
#                                  4         12031.0  13203.00  13225.0
#                           Male   2          4001.0   4726.00   5441.0
#                                  3          7082.0   8125.75   9245.5
#                                  4         11836.0  13028.00  13341.0
# Sales Representative      Female 1          1200.0   2225.50   2572.0
#                                  2          3540.0   4021.00   4502.0
#                           Male   1          1052.0   2269.00   2476.0
#                                  2          2086.0   2251.00   2641.0
#
#                                                 75%      max
# JobRole                   Gender JobLevel
# Healthcare Representative Female 2          6749.00   9824.0
#                                  3         10312.00  10938.0
#                                  4         13965.00  13966.0
#                           Male   2          6563.00   8853.0
#                                  3         10584.50  10999.0
#                                  4         13501.25  13577.0
# Human Resources           Female 1          2922.25   3423.0
#                                  2          6187.00   6389.0
#                                  3          9853.00   9950.0
#                           Male   1          2973.50   4936.0
#                                  2          6328.25   6430.0
#                                  3         10603.50  10725.0
# Laboratory Technician     Female 1          3253.00   4364.0
#                                  2          5363.00   6674.0
#                                  3          7403.00   7403.0
#                           Male   1          3500.00   4876.0
#                                  2          5380.50   6782.0
#                                  3          5338.25   5381.0
# Manager                   Female 3         12810.00  13591.0
#                                  4         17148.50  17875.0
#                                  5         19566.00  19943.0
#                           Male   3         11904.00  13610.0
#                                  4         17246.75  17924.0
#                                  5         19606.25  19999.0
# Manufacturing Director    Female 2          5980.00   6877.0
#                                  3         10384.00  10880.0
#                                  4         13609.00  13826.0
#                           Male   2          6434.00   9957.0
#                                  3         10452.50  10976.0
#                                  4         13830.25  13973.0
# Research Director         Female 3         13511.50  13744.0
#                                  4         16836.00  17328.0
#                                  5         19623.00  19973.0
#                           Male   3         13514.00  13757.0
#                                  4         17588.75  17861.0
#                                  5         19519.50  19740.0
# Research Scientist        Female 1          3361.00   4968.0
#                                  2          5536.00   6962.0
#                           Male   1          3109.50   4930.0
#                                  2          5452.75   6646.0
#                                  3          9724.00   9724.0
# Sales Executive           Female 2          6321.25   9981.0
#                                  3         10248.50  10934.0
#                                  4         13422.50  13770.0
#                           Male   2          6580.00   9998.0
#                                  3         10335.75  10932.0
#                                  4         13726.50  13872.0
# Sales Representative      Female 1          2813.50   3931.0
#                                  2          4953.50   5405.0
#                           Male   1          2858.00   4400.0
#                                  2          3890.00   6632.0

# %%
job_roles = df["JobRole"].unique()

job_roles
# Out:
# ['Sales Executive', 'Research Scientist', 'Laboratory Technician', 'Manufacturing Director', 'Healthcare Representative', 'Manager', 'Sales Representative', 'Research Director', 'Human Resources']
# Categories (9, object): ['Healthcare Representative', 'Human Resources', 'Laboratory Technician', 'Manager', ..., 'Research Director', 'Research Scientist', 'Sales Executive', 'Sales Representative']

# %%
for job in job_roles:
    df[df["JobRole"] == job].boxplot(column="MonthlyIncome", by=["JobLevel", "Gender"], grid=False, showmeans=True)

# %%
for job in job_roles:
    df[df["JobRole"] == job].plot(kind="box", column="MonthlyIncome", by=["JobLevel", "Gender"], grid=False, showmeans=True, title=job)
